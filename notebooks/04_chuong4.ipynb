# %% [markdown]
# # CHƯƠNG 4 - SẢN PHẨM NÀO TẠO HOẶC PHÁ HỦY GIÁ TRỊ?
#
# Chương 4 phân tích portfolio sản phẩm theo cả doanh thu và lợi nhuận. Mục tiêu là tránh kết luận sản phẩm bán chạy luôn tốt, đồng thời phát hiện discount, cost, inventory hoặc cơ cấu bán hàng đang làm giảm margin.
#
# ## Câu hỏi kinh doanh
#
# Sản phẩm/category nào tạo phần lớn doanh thu và lợi nhuận?
# Sản phẩm nào doanh thu cao nhưng gross margin thấp?
# Sản phẩm nào giảm giá nhiều nhưng không tăng đủ số lượng bán?
# Sản phẩm nào có tồn kho cao hoặc demand suy giảm?
# Những sản phẩm nào thường được mua cùng để tối ưu bundle?
#
#
# ## Dữ liệu phân tích
#
# | Thành phần | Thiết kế sử dụng |
# |---|---|
# | Data Mart chính | `mart_product_profitability_monthly kết hợp mart_inventory_risk` |
# | Grain phân tích | Product/Category × Territory × Channel × Month |
# | Nhóm KPI chính | Revenue, Quantity, COGS, Gross Profit, Gross Margin, Discount Rate, ASP, Standard Cost, Inventory Turnover, Days of Inventory |

# %% [markdown]
# ## 1. Cấu hình & kết nối database

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

plt.style.use(
    "seaborn-v0_8-whitegrid"
    if "seaborn-v0_8-whitegrid" in plt.style.available
    else "default"
)
plt.rcParams["figure.figsize"] = (12, 6)
sys.path.append(os.path.abspath(os.path.join('..')))
from src.common.database import get_dwh_engine
engine = get_dwh_engine()

print("Kết nối database DWH thành công!")
# Out:
# Kết nối database DWH thành công!

# %% [markdown]
# ## 2. Kiểm tra cấu trúc Mart

# %%
# Kiểm tra cấu trúc mart_product_profitability_monthly
product_mart_cols = pd.read_sql("""
SELECT column_name, data_type
FROM information_schema.columns
WHERE table_schema = 'mart'
  AND table_name = 'mart_product_profitability_monthly'
ORDER BY ordinal_position;
""", engine)

product_mart_cols
# Out:
#           column_name          data_type
# 0           month_key               text
# 1        territory_id            integer
# 2     territory_group  character varying
# 3        country_code  character varying
# 4             channel               text
# 5         product_key            integer
# 6        product_name  character varying
# 7       category_name  character varying
# 8    subcategory_name  character varying
# 9              orders             bigint
# 10           quantity             bigint
# 11            revenue            numeric
# 12               cogs            numeric
# 13       gross_profit            numeric
# 14       gross_margin            numeric
# 15     avg_unit_price            numeric
# 16  avg_discount_rate            numeric
# 17  avg_standard_cost            numeric

# %%
# Xem dữ liệu mẫu mart_product_profitability_monthly
product_mart_sample = pd.read_sql("""
SELECT *
FROM mart.mart_product_profitability_monthly
LIMIT 10;
""", engine)

product_mart_sample
# Out:
#   month_key  territory_id territory_group country_code channel  product_key  \
# 0    202205             1   North America           US     B2B           25
# 1    202205             1   North America           US     B2B           26
# 2    202205             1   North America           US     B2B           27
# 3    202205             1   North America           US     B2B           28
# 4    202205             1   North America           US     B2B           29
# 5    202205             1   North America           US     B2B           30
# 6    202205             1   North America           US     B2B           31
# 7    202205             1   North America           US     B2B           32
# 8    202205             1   North America           US     B2B           54
# 9    202205             1   North America           US     B2B           56
#
#               product_name category_name subcategory_name  orders  quantity  \
# 0   Mountain-100 Black, 48         Bikes   Mountain Bikes       3         7
# 1   Mountain-100 Black, 44         Bikes   Mountain Bikes       3        10
# 2   Mountain-100 Black, 42         Bikes   Mountain Bikes       2         3
# 3   Mountain-100 Black, 38         Bikes   Mountain Bikes       3        10
# 4  Mountain-100 Silver, 48         Bikes   Mountain Bikes       1         1
# 5  Mountain-100 Silver, 44         Bikes   Mountain Bikes       3         4
# 6  Mountain-100 Silver, 42         Bikes   Mountain Bikes       2         2
# 7  Mountain-100 Silver, 38         Bikes   Mountain Bikes       1         3
# 8       Road-650 Black, 52         Bikes       Road Bikes       1         1
# 9       Road-650 Black, 44         Bikes       Road Bikes       1         2
#
#     revenue      cogs  gross_profit  gross_margin  avg_unit_price  \
# 0 14,174.96 13,286.66        888.30          0.06        2,024.99
# 1 20,249.94 18,980.94      1,269.00          0.06        2,024.99
# 2  6,074.98  5,694.28        380.70          0.06        2,024.99
# 3 20,249.94 18,980.94      1,269.00          0.06        2,024.99
# 4  2,039.99  1,912.15        127.84          0.06        2,039.99
# 5  8,159.98  7,648.62        511.36          0.06        2,039.99
# 6  4,079.99  3,824.31        255.68          0.06        2,039.99
# 7  6,119.98  5,736.46        383.52          0.06        2,039.99
# 8    419.46    486.71        -67.25         -0.16          419.46
# 9    838.92    973.41       -134.50         -0.16          419.46
#
#    avg_discount_rate  avg_standard_cost
# 0               0.00           1,898.09
# 1               0.00           1,898.09
# 2               0.00           1,898.09
# 3               0.00           1,898.09
# 4               0.00           1,912.15
# 5               0.00           1,912.15
# 6               0.00           1,912.15
# 7               0.00           1,912.15
# 8               0.00             486.71
# 9               0.00             486.71

# %%
# Kiểm tra cấu trúc mart_inventory_risk
inventory_mart_cols = pd.read_sql("""
SELECT column_name, data_type
FROM information_schema.columns
WHERE table_schema = 'mart'
  AND table_name = 'mart_inventory_risk'
ORDER BY ordinal_position;
""", engine)

inventory_mart_cols
# Out:
#                column_name          data_type
# 0              product_key            integer
# 1             product_name  character varying
# 2            category_name  character varying
# 3         subcategory_name  character varying
# 4               units_sold             bigint
# 5                  revenue            numeric
# 6                     cogs            numeric
# 7             gross_profit            numeric
# 8             gross_margin            numeric
# 9    current_inventory_qty             bigint
# 10       avg_inventory_qty            numeric
# 11       max_inventory_qty            integer
# 12       min_inventory_qty            integer
# 13       inventory_records             bigint
# 14  inventory_turnover_qty             bigint
# 15    days_inventory_proxy             bigint
# 16   inventory_risk_status               text

# %%
# Xem dữ liệu mẫu mart_inventory_risk
inventory_sample = pd.read_sql("""
SELECT *
FROM mart.mart_inventory_risk
LIMIT 10;
""", engine)

inventory_sample
# Out:
#    product_key             product_name category_name subcategory_name  \
# 0          384               Lock Nut 7          None             None
# 1          351           Lock Washer 11          None             None
# 2          116          Rear Derailleur    Components      Derailleurs
# 3           87  Touring-3000 Yellow, 54         Bikes    Touring Bikes
# 4          477            Flat Washer 8          None             None
# 5          273    Fender Set - Mountain   Accessories          Fenders
# 6          394     Thin-Jam Lock Nut 13          None             None
# 7           51         Road-250 Red, 52         Bikes       Road Bikes
# 8          272    Bike Wash - Dissolver   Accessories         Cleaners
# 9           70         Road-450 Red, 58         Bikes       Road Bikes
#
#    units_sold      revenue       cogs  gross_profit  gross_margin  \
# 0           0         0.00       0.00          0.00           NaN
# 1           0         0.00       0.00          0.00           NaN
# 2         353    25,725.23  19,036.65      6,688.57          0.26
# 3         453   196,809.98 209,034.49    -12,224.52         -0.06
# 4           0         0.00       0.00          0.00           NaN
# 5        2121    46,619.58  17,435.68     29,183.90          0.63
# 6           0         0.00       0.00          0.00           NaN
# 7         639 1,066,766.61 970,504.51     96,262.10          0.09
# 8        3319    18,406.97   9,868.38      8,538.59          0.46
# 9         582   507,978.30 514,900.23     -6,921.93         -0.01
#
#    current_inventory_qty  avg_inventory_qty  max_inventory_qty  \
# 0                   1661             553.67                630
# 1                   1743             581.00                640
# 2                    847             282.33                355
# 3                    162              81.00                126
# 4                    896             298.67                332
# 5                    108             108.00                108
# 6                   1613             537.67                614
# 7                    148              74.00                 81
# 8                     36              36.00                 36
# 9                    148              74.00                 83
#
#    min_inventory_qty  inventory_records  inventory_turnover_qty  \
# 0                507                  3                       0
# 1                518                  3                       0
# 2                155                  3                       0
# 3                 36                  2                       2
# 4                246                  3                       0
# 5                108                  1                      19
# 6                491                  3                       0
# 7                 67                  2                       4
# 8                 36                  1                      92
# 9                 65                  2                       3
#
#    days_inventory_proxy       inventory_risk_status
# 0                   NaN  No Demand - Overstock Risk
# 1                   NaN  No Demand - Overstock Risk
# 2                 60.00                 Slow Moving
# 3                  0.00                     Healthy
# 4                   NaN  No Demand - Overstock Risk
# 5                  0.00                     Healthy
# 6                   NaN  No Demand - Overstock Risk
# 7                  0.00                     Healthy
# 8                  0.00                     Healthy
# 9                  0.00                     Healthy

# %%
# Đọc toàn bộ dữ liệu từ 2 mart
product_df = pd.read_sql("""
SELECT *
FROM mart.mart_product_profitability_monthly;
""", engine)

inventory_df = pd.read_sql("""
SELECT *
FROM mart.mart_inventory_risk;
""", engine)

print("Product Profitability Mart:", product_df.shape)
print("Inventory Risk Mart:", inventory_df.shape)
# Out:
# Product Profitability Mart: (32674, 18)
# Inventory Risk Mart: (488, 17)

# %%
# Kiểm tra grain của Product Profitability Mart
# Grain kỳ vọng: Month × Territory × Channel × Product

product_grain_cols = [
    "month_key",
    "territory_id",
    "channel",
    "product_key"
]

product_grain_check = (
    product_df.groupby(product_grain_cols)
    .size()
    .reset_index(name="row_count")
)

product_grain_violations = product_grain_check[
    product_grain_check["row_count"] > 1
]

product_grain_violations
# Out:
# Empty DataFrame
# Columns: [month_key, territory_id, channel, product_key, row_count]
# Index: []

# %%
# Kiểm tra grain của Inventory Risk Mart
# Grain kỳ vọng: Product

inventory_grain_cols = ["product_key"]

inventory_grain_check = (
    inventory_df.groupby(inventory_grain_cols)
    .size()
    .reset_index(name="row_count")
)

inventory_grain_violations = inventory_grain_check[
    inventory_grain_check["row_count"] > 1
]

inventory_grain_violations
# Out:
# Empty DataFrame
# Columns: [product_key, row_count]
# Index: []

# %%
# Tóm tắt kết quả kiểm tra cấu trúc mart
mart_structure_summary = pd.DataFrame({
    "Mart": [
        "mart_product_profitability_monthly",
        "mart_inventory_risk"
    ],
    "Expected Grain": [
        "Month × Territory × Channel × Product",
        "Product"
    ],
    "Rows": [
        product_df.shape[0],
        inventory_df.shape[0]
    ],
    "Columns": [
        product_df.shape[1],
        inventory_df.shape[1]
    ],
    "Duplicate Grain Rows": [
        product_grain_violations.shape[0],
        inventory_grain_violations.shape[0]
    ],
    "Status": [
        "PASS" if product_grain_violations.empty else "CHECK",
        "PASS" if inventory_grain_violations.empty else "CHECK"
    ]
})

mart_structure_summary
# Out:
#                                  Mart                         Expected Grain  \
# 0  mart_product_profitability_monthly  Month × Territory × Channel × Product
# 1                 mart_inventory_risk                                Product
#
#     Rows  Columns  Duplicate Grain Rows Status
# 0  32674       18                     0   PASS
# 1    488       17                     0   PASS

# %% [markdown]
# ### Nhận xét
#
# Kết quả kiểm tra cho thấy Chương 4 sử dụng hai mart với hai mức grain khác nhau.
#
# Mart `mart_product_profitability_monthly` được xây dựng theo grain **Month × Territory × Channel × Product**, phù hợp để phân tích doanh thu, lợi nhuận, gross margin, discount và cơ cấu bán hàng theo thời gian, khu vực và kênh bán hàng.
#
# Mart `mart_inventory_risk` được xây dựng theo grain **Product**, dùng để phân tích rủi ro tồn kho. Lý do không phân tích inventory theo tháng là vì dữ liệu `fact_inventory` không có snapshot đầy đủ theo từng tháng. Nếu ép join tồn kho theo Month × Product, kết quả sẽ tạo ra nhiều giá trị tồn kho bằng 0 không phản ánh đúng thực tế.
#
# Do đó, trong Chương 4, phần profitability được phân tích theo grain chi tiết **Product/Category × Territory × Channel × Month**, còn phần inventory risk được phân tích ở cấp **Product** để đảm bảo kết quả đáng tin cậy.

# %% [markdown]
# ## 3. Khám phá dữ liệu (EDA)

# %%
# # Kiểm tra kích thước dữ liệu
print(product_df.shape)
print(inventory_df.shape)

# Kiểm tra datatype
product_df.info()
inventory_df.info()

# Missing Values
product_df.isnull().sum()
inventory_df.isnull().sum()

# duplicate
product_df.duplicated().sum()
inventory_df.duplicated().sum()

# Thống kê mô tả
inventory_df.duplicated().sum()

# Distribution Revenue
plt.figure(figsize=(8,5))

plt.hist(product_df["revenue"], bins=30)

plt.title("Distribution of Product Revenue")

plt.xlabel("Revenue")

plt.ylabel("Frequency")

plt.show()

# Distribution Gross Margin
plt.figure(figsize=(8,5))

plt.hist(product_df["gross_margin"], bins=30)

plt.title("Distribution of Gross Margin")

plt.show()

# Revenue theo Category
category = (
    product_df.groupby("category_name")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

category.plot.bar()

plt.title("Revenue by Category")

plt.show()

# Inventory Status
inventory_df["inventory_risk_status"].value_counts().plot.bar()

plt.title("Inventory Risk Status")

plt.show()

# Correlation Matrix
import seaborn as sns

numeric = product_df.select_dtypes(include="number")

corr = numeric.corr()

plt.figure(figsize=(10,6))

sns.heatmap(
    corr,
    annot=True,
    cmap="RdBu_r",
    fmt=".2f"
)

plt.title("Correlation Matrix")

plt.show()
# Out:
# (32674, 18)
# (488, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32674 entries, 0 to 32673
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month_key          32674 non-null  object
#  1   territory_id       32674 non-null  int64
#  2   territory_group    32674 non-null  object
#  3   country_code       32674 non-null  object
#  4   channel            32674 non-null  object
#  5   product_key        32674 non-null  int64
#  6   product_name       32674 non-null  object
#  7   category_name      32674 non-null  object
#  8   subcategory_name   32674 non-null  object
#  9   orders             32674 non-null  int64
#  10  quantity           32674 non-null  int64
#  11  revenue            32674 non-null  float64
#  12  cogs               32674 non-null  float64
#  13  gross_profit       32674 non-null  float64
#  14  gross_margin       32674 non-null  float64
#  15  avg_unit_price     32674 non-null  float64
#  16  avg_discount_rate  32674 non-null  float64
#  17  avg_standard_cost  32674 non-null  float64
# dtypes: float64(7), int64(4), object(7)
# memory usage: 4.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_key             488 non-null    int64
#  1   product_name            488 non-null    object
#  2   category_name           279 non-null    object
#  3   subcategory_name        279 non-null    object
#  4   units_sold              488 non-null    int64
#  5   revenue                 488 non-null    float64
#  6   cogs                    488 non-null    float64
#  7   gross_profit            488 non-null    float64
#  8   gross_margin            266 non-null    float64
#  9   current_inventory_qty   488 non-null    int64
#  10  avg_inventory_qty       488 non-null    float64
#  11  max_inventory_qty       488 non-null    int64
#  12  min_inventory_qty       488 non-null    int64
#  13  inventory_records       488 non-null    int64
#  14  inventory_turnover_qty  428 non-null    float64
#  15  days_inventory_proxy    266 non-null    float64
#  16  inventory_risk_status   488 non-null    object
# dtypes: float64(7), int64(6), object(4)
# memory usage: 64.9+ KB

# %% [markdown]
# ## 5. Phân tích

# %% [markdown]
# 5.1 Chuẩn hóa lợi nhuận
#
# - Đảm bảo tất cả các chỉ số lợi nhuận được tính trên cùng một đơn vị tiền tệ (USD), kiểm tra dữ liệu chi phí trước khi thực hiện các phân tích Product Portfolio.

# %%
# Đọc Product Profitability Mart
profit_df = pd.read_sql("""
SELECT *
FROM mart.mart_product_profitability_monthly;
""", engine)

profit_df.head()
# Out:
#   month_key  territory_id territory_group country_code channel  product_key  \
# 0    202205             1   North America           US     B2B           25
# 1    202205             1   North America           US     B2B           26
# 2    202205             1   North America           US     B2B           27
# 3    202205             1   North America           US     B2B           28
# 4    202205             1   North America           US     B2B           29
#
#               product_name category_name subcategory_name  orders  quantity  \
# 0   Mountain-100 Black, 48         Bikes   Mountain Bikes       3         7
# 1   Mountain-100 Black, 44         Bikes   Mountain Bikes       3        10
# 2   Mountain-100 Black, 42         Bikes   Mountain Bikes       2         3
# 3   Mountain-100 Black, 38         Bikes   Mountain Bikes       3        10
# 4  Mountain-100 Silver, 48         Bikes   Mountain Bikes       1         1
#
#     revenue      cogs  gross_profit  gross_margin  avg_unit_price  \
# 0 14,174.96 13,286.66        888.30          0.06        2,024.99
# 1 20,249.94 18,980.94      1,269.00          0.06        2,024.99
# 2  6,074.98  5,694.28        380.70          0.06        2,024.99
# 3 20,249.94 18,980.94      1,269.00          0.06        2,024.99
# 4  2,039.99  1,912.15        127.84          0.06        2,039.99
#
#    avg_discount_rate  avg_standard_cost
# 0               0.00           1,898.09
# 1               0.00           1,898.09
# 2               0.00           1,898.09
# 3               0.00           1,898.09
# 4               0.00           1,912.15

# %%
# Kiểm tra missing values
profit_df.isnull().sum()
# Out:
# month_key            0
# territory_id         0
# territory_group      0
# country_code         0
# channel              0
# product_key          0
# product_name         0
# category_name        0
# subcategory_name     0
# orders               0
# quantity             0
# revenue              0
# cogs                 0
# gross_profit         0
# gross_margin         0
# avg_unit_price       0
# avg_discount_rate    0
# avg_standard_cost    0
# dtype: int64

# %%
# Kiểm tra Cost Missing
cost_missing = (
    profit_df["cogs"].isna().sum()
)

print(f"Missing COGS: {cost_missing}")
# Out:
# Missing COGS: 0

# %%
# Kiểm tra Revenue
profit_df["check_difference"] = (
    profit_df["revenue"]
    - profit_df["cogs"]
    - profit_df["gross_profit"]
)

profit_df["check_difference"].describe()
# Out:
# count   32,674.00
# mean         0.00
# std          0.00
# min         -0.00
# 25%         -0.00
# 50%          0.00
# 75%          0.00
# max          0.00
# Name: check_difference, dtype: float64

# %%
# Kiểm tra số dòng sai
profit_df[
    profit_df["check_difference"].abs() > 0.01
]
# Out:
# Empty DataFrame
# Columns: [month_key, territory_id, territory_group, country_code, channel, product_key, product_name, category_name, subcategory_name, orders, quantity, revenue, cogs, gross_profit, gross_margin, avg_unit_price, avg_discount_rate, avg_standard_cost, check_difference]
# Index: []

# %%
# Kiểm tra Gross Margin
profit_df["gross_margin_check"] = (
    profit_df["gross_profit"] /
    profit_df["revenue"]
)

comparison = profit_df[
    [
        "gross_margin",
        "gross_margin_check"
    ]
]

comparison.head()
# Out:
#    gross_margin  gross_margin_check
# 0          0.06                0.06
# 1          0.06                0.06
# 2          0.06                0.06
# 3          0.06                0.06
# 4          0.06                0.06

# %%
# Kiểm tra sai số
(
    (
        profit_df["gross_margin"]
        - profit_df["gross_margin_check"]
    )
    .abs()
    .max()
)
# Out:
# 4.440892098500626e-16

# %%
# Product Profitability Table
product_profitability = (
    profit_df
    .groupby(
        [
            "product_key",
            "product_name",
            "category_name",
            "subcategory_name"
        ],
        as_index=False
    )
    .agg(
        Revenue=("revenue", "sum"),
        COGS=("cogs", "sum"),
        Gross_Profit=("gross_profit", "sum"),
        Units_Sold=("quantity", "sum"),
        Avg_Price=("avg_unit_price", "mean"),
        Avg_Discount=("avg_discount_rate", "mean")
    )
)

product_profitability["Gross_Margin"] = (
    product_profitability["Gross_Profit"]
    / product_profitability["Revenue"]
)

product_profitability.head()
# Out:
#    product_key            product_name category_name subcategory_name  \
# 0            1  Mountain-500 Black, 52         Bikes   Mountain Bikes
# 1            2  Mountain-500 Black, 48         Bikes   Mountain Bikes
# 2            3  Mountain-500 Black, 44         Bikes   Mountain Bikes
# 3            4  Mountain-500 Black, 42         Bikes   Mountain Bikes
# 4            5  Mountain-500 Black, 40         Bikes   Mountain Bikes
#
#      Revenue       COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 0  96,982.20  80,125.68     16,856.53         272     394.57          0.00
# 1 157,569.08 132,266.29     25,302.80         449     393.55          0.00
# 2 125,925.67 103,102.90     22,822.77         350     401.68          0.00
# 3 136,293.48 114,296.92     21,996.55         388     401.83          0.00
# 4 101,734.12  83,071.48     18,662.64         282     400.11          0.00
#
#    Gross_Margin
# 0          0.17
# 1          0.16
# 2          0.18
# 3          0.16
# 4          0.18

# %%
# Top Profit Products
product_profitability.sort_values(
    "Gross_Profit",
    ascending=False
).head(10)
# Out:
#     product_key             product_name category_name subcategory_name  \
# 19           20   Mountain-200 Black, 42         Bikes   Mountain Bikes
# 20           21   Mountain-200 Black, 38         Bikes   Mountain Bikes
# 18           19   Mountain-200 Black, 46         Bikes   Mountain Bikes
# 23           24  Mountain-200 Silver, 38         Bikes   Mountain Bikes
# 21           22  Mountain-200 Silver, 46         Bikes   Mountain Bikes
# 22           23  Mountain-200 Silver, 42         Bikes   Mountain Bikes
# 72           73         Road-150 Red, 48         Bikes       Road Bikes
# 74           75         Road-150 Red, 62         Bikes       Road Bikes
# 71           72         Road-150 Red, 52         Bikes       Road Bikes
# 70           71         Road-150 Red, 56         Bikes       Road Bikes
#
#         Revenue         COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 19 4,009,494.76 3,335,278.18    674,216.58        2664   1,710.52
# 20 4,400,592.80 3,727,148.33    673,444.47        2977   1,684.97
# 18 3,309,673.22 2,642,932.52    666,740.69        2111   1,713.22
# 23 3,693,678.03 3,029,893.08    663,784.94        2394   1,735.39
# 21 3,434,256.94 2,804,612.81    629,644.13        2216   1,728.27
# 22 3,438,478.86 2,827,393.96    611,084.90        2234   1,724.51
# 72 1,540,803.06 1,070,448.04    470,355.02         493   3,064.47
# 74 1,769,096.69 1,302,776.52    466,320.17         600   2,954.09
# 71 1,415,563.61   994,452.74    421,110.87         458   3,026.86
# 70 1,847,818.63 1,441,739.35    406,079.28         664   2,907.66
#
#     Avg_Discount  Gross_Margin
# 19          0.00          0.17
# 20          0.00          0.15
# 18          0.00          0.20
# 23          0.00          0.18
# 21          0.00          0.18
# 22          0.00          0.18
# 72          0.00          0.31
# 74          0.00          0.26
# 71          0.00          0.30
# 70          0.00          0.22

# %%
# Top Margin Products
product_profitability.sort_values(
    "Gross_Margin",
    ascending=False
).head(10)
# Out:
#      product_key            product_name category_name   subcategory_name  \
# 248          273   Fender Set - Mountain   Accessories            Fenders
# 259          289        HL Mountain Tire   Accessories    Tires and Tubes
# 243          268  All-Purpose Bike Stand   Accessories        Bike Stands
# 256          286            HL Road Tire   Accessories    Tires and Tubes
# 260          290        ML Mountain Tire   Accessories    Tires and Tubes
# 255          285            Touring Tire   Accessories    Tires and Tubes
# 257          287            ML Road Tire   Accessories    Tires and Tubes
# 261          291        LL Mountain Tire   Accessories    Tires and Tubes
# 258          288            LL Road Tire   Accessories    Tires and Tubes
# 245          270    Mountain Bottle Cage   Accessories  Bottles and Cages
#
#       Revenue      COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 248 46,619.58 17,435.68     29,183.90        2121      21.98          0.00
# 259 48,860.00 18,273.64     30,586.36        1396      35.00          0.00
# 243 39,591.00 14,807.03     24,783.97         249     159.00          0.00
# 256 27,970.80 10,461.08     17,509.72         858      32.60          0.00
# 260 34,818.39 13,022.12     21,796.27        1161      29.99          0.00
# 255 27,105.65 10,137.55     16,968.10         935      28.99          0.00
# 257 23,140.74  8,654.67     14,486.07         926      24.99          0.00
# 261 21,541.38  8,056.51     13,484.87         862      24.99          0.00
# 258 22,435.56  8,390.94     14,044.62        1044      21.49          0.00
# 245 20,229.75  7,566.01     12,663.74        2025       9.99          0.00
#
#      Gross_Margin
# 248          0.63
# 259          0.63
# 243          0.63
# 256          0.63
# 260          0.63
# 255          0.63
# 257          0.63
# 261          0.63
# 258          0.63
# 245          0.63

# %% [markdown]
# ### Nhận xét
#
# Kết quả kiểm tra cho thấy dữ liệu lợi nhuận trong `mart_product_profitability_monthly` không có giá trị thiếu tại các chỉ số chính như Revenue, COGS và Gross Profit. Đồng thời, công thức Revenue = COGS + Gross Profit và Gross Margin = Gross Profit / Revenue được xác nhận là nhất quán trên toàn bộ dữ liệu.
#
# Bảng Product Profitability sau khi chuẩn hóa sẽ là nguồn dữ liệu chính cho các phân tích tiếp theo như Product Portfolio Matrix, ABC Analysis, Discount Analysis và Product Clustering.

# %% [markdown]
# 5.2 Portfolio Matrix
#
# - Mục tiêu
#
#     Phân loại danh mục sản phẩm dựa trên hai chỉ tiêu:
#
#     + Revenue (mức đóng góp doanh thu)
#     + Gross Margin (khả năng tạo lợi nhuận)
#
# - Sau đó bổ sung:
#
#     + Inventory Risk
#     + Growth Rate
#
# để hỗ trợ ra quyết định quản trị.

# %%
# Tạo bảng Product Protfolio
portfolio = product_profitability.copy()

portfolio.head()
# Out:
#    product_key            product_name category_name subcategory_name  \
# 0            1  Mountain-500 Black, 52         Bikes   Mountain Bikes
# 1            2  Mountain-500 Black, 48         Bikes   Mountain Bikes
# 2            3  Mountain-500 Black, 44         Bikes   Mountain Bikes
# 3            4  Mountain-500 Black, 42         Bikes   Mountain Bikes
# 4            5  Mountain-500 Black, 40         Bikes   Mountain Bikes
#
#      Revenue       COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 0  96,982.20  80,125.68     16,856.53         272     394.57          0.00
# 1 157,569.08 132,266.29     25,302.80         449     393.55          0.00
# 2 125,925.67 103,102.90     22,822.77         350     401.68          0.00
# 3 136,293.48 114,296.92     21,996.55         388     401.83          0.00
# 4 101,734.12  83,071.48     18,662.64         282     400.11          0.00
#
#    Gross_Margin
# 0          0.17
# 1          0.16
# 2          0.18
# 3          0.16
# 4          0.18

# %%
# Tính Growth
growth = (
    profit_df
    .groupby(["product_key", "month_key"], as_index=False)
    .agg(
        Revenue=("revenue", "sum")
    )
)

growth["Growth"] = (
    growth
    .groupby("product_key")["Revenue"]
    .pct_change()
)

growth.head()
# Out:
#    product_key month_key   Revenue  Growth
# 0            1    202405  3,239.94     NaN
# 1            1    202406 10,259.81    2.17
# 2            1    202407  6,587.88   -0.36
# 3            1    202408  6,695.88    0.02
# 4            1    202409  6,911.87    0.03

# %%
# Growth trung bình
growth_summary = (
    growth
    .groupby("product_key", as_index=False)
    .agg(
        Avg_Growth=("Growth", "mean")
    )
)

growth_summary.head()
# Out:
#    product_key  Avg_Growth
# 0            1        0.14
# 1            2        0.01
# 2            3        0.11
# 3            4        0.05
# 4            5       -0.04

# %%
# Ghép Inventory Risk
inventory = inventory_df[
    [
        "product_key",
        "inventory_risk_status",
        "inventory_turnover_qty",
        "days_inventory_proxy"
    ]
]

portfolio = portfolio.merge(
    growth_summary,
    on="product_key",
    how="left"
)

portfolio = portfolio.merge(
    inventory,
    on="product_key",
    how="left"
)

portfolio.head()
# Out:
#    product_key            product_name category_name subcategory_name  \
# 0            1  Mountain-500 Black, 52         Bikes   Mountain Bikes
# 1            2  Mountain-500 Black, 48         Bikes   Mountain Bikes
# 2            3  Mountain-500 Black, 44         Bikes   Mountain Bikes
# 3            4  Mountain-500 Black, 42         Bikes   Mountain Bikes
# 4            5  Mountain-500 Black, 40         Bikes   Mountain Bikes
#
#      Revenue       COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 0  96,982.20  80,125.68     16,856.53         272     394.57          0.00
# 1 157,569.08 132,266.29     25,302.80         449     393.55          0.00
# 2 125,925.67 103,102.90     22,822.77         350     401.68          0.00
# 3 136,293.48 114,296.92     21,996.55         388     401.83          0.00
# 4 101,734.12  83,071.48     18,662.64         282     400.11          0.00
#
#    Gross_Margin  Avg_Growth inventory_risk_status  inventory_turnover_qty  \
# 0          0.17        0.14               Healthy                    1.00
# 1          0.16        0.01               Healthy                    2.00
# 2          0.18        0.11               Healthy                    2.00
# 3          0.16        0.05               Healthy                    2.00
# 4          0.18       -0.04               Healthy                    1.00
#
#    days_inventory_proxy
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00

# %%
# Tìm Median: dùng để chia portfolio
revenue_cut = portfolio["Revenue"].median()

margin_cut = portfolio["Gross_Margin"].median()

print(revenue_cut)
print(margin_cut)

# Không dùng mean vì renuve thường lệch rất mạnh
# Out:
# 117570.685863
# 0.10532538084091425

# %%
# Phân loại Portfolio
def classify(row):

    if (
        row["Revenue"] >= revenue_cut
        and
        row["Gross_Margin"] >= margin_cut
    ):
        return "Star"

    elif (
        row["Revenue"] >= revenue_cut
        and
        row["Gross_Margin"] < margin_cut
    ):
        return "Volume-Low Margin"

    elif (
        row["Revenue"] < revenue_cut
        and
        row["Gross_Margin"] >= margin_cut
    ):
        return "Niche-High Margin"

    else:
        return "Weak"

# Áp dụng:
portfolio["Portfolio"] = portfolio.apply(
    classify,
    axis=1
)

# %%
# Thống kê
portfolio["Portfolio"].value_counts()
# Out:
# Portfolio
# Niche-High Margin    95
# Volume-Low Margin    95
# Star                 38
# Weak                 38
# Name: count, dtype: int64

# %%
# Bubble Chart
plt.figure(figsize=(12,8))

plt.scatter(

    portfolio["Revenue"],

    portfolio["Gross_Margin"],

    s=portfolio["Units_Sold"]/5,

    alpha=0.7

)

plt.axvline(
    revenue_cut,
    color="red",
    linestyle="--"
)

plt.axhline(
    margin_cut,
    color="red",
    linestyle="--"
)

plt.xlabel("Revenue")

plt.ylabel("Gross Margin")

plt.title("Product Portfolio Matrix")

plt.show()

# %%
# Làm sạch dữ liệu trước khi vẽ
portfolio_plot = portfolio.copy()

portfolio_plot["Avg_Growth"] = portfolio_plot["Avg_Growth"].fillna(0)
portfolio_plot["Units_Sold"] = portfolio_plot["Units_Sold"].fillna(0)

# Size bubble
bubble_size = (
    portfolio_plot["Units_Sold"] / portfolio_plot["Units_Sold"].max() * 1000
)

plt.figure(figsize=(14, 8))

scatter = plt.scatter(
    portfolio_plot["Revenue"],
    portfolio_plot["Gross_Margin"],
    s=bubble_size,
    c=portfolio_plot["Avg_Growth"],
    cmap="RdYlGn",
    alpha=0.7
)

plt.axvline(revenue_cut, linestyle="--")
plt.axhline(margin_cut, linestyle="--")

plt.xlabel("Revenue")
plt.ylabel("Gross Margin")
plt.title("Product Portfolio Matrix: Revenue vs Gross Margin")

plt.colorbar(scatter, label="Average Revenue Growth")

# Hiển thị tên Top Revenue Products
top_products = portfolio_plot.sort_values("Revenue", ascending=False).head(5)

for _, row in top_products.iterrows():
    plt.text(
        row["Revenue"],
        row["Gross_Margin"],
        row["product_name"],
        fontsize=8
    )

plt.show()

# %%
# Đếm từng nhóm
portfolio_summary = (
    portfolio
    .groupby("Portfolio")
    .agg(
        Products=("product_key", "count"),
        Revenue=("Revenue", "sum"),
        Gross_Profit=("Gross_Profit", "sum"),
        Units_Sold=("Units_Sold", "sum"),
        Avg_Margin=("Gross_Margin", "mean"),
        Avg_Growth=("Avg_Growth", "mean")
    )
    .reset_index()
    .sort_values("Revenue", ascending=False)
)

portfolio_summary
# Out:
#            Portfolio  Products       Revenue  Gross_Profit  Units_Sold  \
# 2  Volume-Low Margin        95 67,522,631.36    850,331.98       93286
# 1               Star        38 37,245,250.46  7,578,907.77       62376
# 0  Niche-High Margin        95  3,081,869.86    990,563.16       92837
# 3               Weak        38  1,996,629.72    -47,899.28       26415
#
#    Avg_Margin  Avg_Growth
# 2       -0.00        0.25
# 1        0.24        0.21
# 0        0.34        0.46
# 3       -0.00        1.08

# %%
# Top Star Products
portfolio[
    portfolio["Portfolio"]=="Star"
].sort_values(
    "Revenue",
    ascending=False
).head(10)
# Out:
#     product_key             product_name category_name subcategory_name  \
# 20           21   Mountain-200 Black, 38         Bikes   Mountain Bikes
# 19           20   Mountain-200 Black, 42         Bikes   Mountain Bikes
# 23           24  Mountain-200 Silver, 38         Bikes   Mountain Bikes
# 22           23  Mountain-200 Silver, 42         Bikes   Mountain Bikes
# 21           22  Mountain-200 Silver, 46         Bikes   Mountain Bikes
# 18           19   Mountain-200 Black, 46         Bikes   Mountain Bikes
# 70           71         Road-150 Red, 56         Bikes       Road Bikes
# 74           75         Road-150 Red, 62         Bikes       Road Bikes
# 72           73         Road-150 Red, 48         Bikes       Road Bikes
# 71           72         Road-150 Red, 52         Bikes       Road Bikes
#
#         Revenue         COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 20 4,400,592.80 3,727,148.33    673,444.47        2977   1,684.97
# 19 4,009,494.76 3,335,278.18    674,216.58        2664   1,710.52
# 23 3,693,678.03 3,029,893.08    663,784.94        2394   1,735.39
# 22 3,438,478.86 2,827,393.96    611,084.90        2234   1,724.51
# 21 3,434,256.94 2,804,612.81    629,644.13        2216   1,728.27
# 18 3,309,673.22 2,642,932.52    666,740.69        2111   1,713.22
# 70 1,847,818.63 1,441,739.35    406,079.28         664   2,907.66
# 74 1,769,096.69 1,302,776.52    466,320.17         600   2,954.09
# 72 1,540,803.06 1,070,448.04    470,355.02         493   3,064.47
# 71 1,415,563.61   994,452.74    421,110.87         458   3,026.86
#
#     Avg_Discount  Gross_Margin  Avg_Growth inventory_risk_status  \
# 20          0.00          0.15        0.10               Healthy
# 19          0.00          0.17        0.07               Healthy
# 23          0.00          0.18        0.06               Healthy
# 22          0.00          0.18        0.06               Healthy
# 21          0.00          0.18        0.07               Healthy
# 18          0.00          0.20        0.04               Healthy
# 70          0.00          0.22        0.32               Healthy
# 74          0.00          0.26        0.57               Healthy
# 72          0.00          0.31        0.08               Healthy
# 71          0.00          0.30        0.12               Healthy
#
#     inventory_turnover_qty  days_inventory_proxy Portfolio
# 20                   15.00                  0.00      Star
# 19                   18.00                  0.00      Star
# 23                   17.00                  0.00      Star
# 22                   10.00                  0.00      Star
# 21                   15.00                  0.00      Star
# 18                   15.00                  0.00      Star
# 70                    4.00                  0.00      Star
# 74                    4.00                  0.00      Star
# 72                    3.00                  0.00      Star
# 71                    3.00                  0.00      Star

# %%
# Weak Products
portfolio[
    portfolio["Portfolio"]=="Weak"
].sort_values(
    "Revenue"
).head(10)
# Out:
#      product_key                      product_name category_name  \
# 185          206       LL Touring Frame - Blue, 58    Components
# 120          124     LL Mountain Frame - Black, 40    Components
# 121          125  ML Mountain Frame-W - Silver, 38    Components
# 122          126     LL Mountain Frame - Black, 52    Components
# 184          205       LL Touring Frame - Blue, 62    Components
# 180          200       LL Touring Frame - Blue, 44    Components
# 127          131    LL Mountain Frame - Silver, 48    Components
# 181          201     LL Touring Frame - Yellow, 58    Components
# 164          178           LL Road Frame - Red, 52    Components
# 167          182         LL Road Frame - Black, 60    Components
#
#     subcategory_name   Revenue      COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 185   Touring Frames    800.21    799.41          0.80           4     200.05
# 120  Mountain Frames  1,198.99  1,094.28        104.71           8     149.87
# 121  Mountain Frames  1,529.18  1,395.63        133.55           7     218.45
# 122  Mountain Frames  2,248.11  2,051.78        196.34          15     149.87
# 184   Touring Frames  3,000.78  2,997.78          3.00          15     200.05
# 180   Touring Frames  5,001.30  4,996.30          5.00          25     200.05
# 127  Mountain Frames  6,970.92  6,362.13        608.79          44     158.43
# 181   Touring Frames  7,201.87  7,194.67          7.20          36     200.05
# 164      Road Frames 20,104.44 18,715.71      1,388.73         100     199.18
# 167      Road Frames 24,844.69 26,396.64     -1,551.95         129     192.96
#
#      Avg_Discount  Gross_Margin  Avg_Growth   inventory_risk_status  \
# 185          0.00          0.00         NaN  Demand - Low Inventory
# 120          0.00          0.09        6.00             Slow Moving
# 121          0.00          0.09        5.00             Slow Moving
# 122          0.00          0.09        5.50  Demand - Low Inventory
# 184          0.00          0.00        3.78  Demand - Low Inventory
# 180          0.00          0.00        2.63  Demand - Low Inventory
# 127          0.00          0.09        0.80  Demand - Low Inventory
# 181          0.00          0.00        1.34  Demand - Low Inventory
# 164          0.00          0.07        2.32  Demand - Low Inventory
# 167          0.00         -0.06        4.02  Demand - Low Inventory
#
#      inventory_turnover_qty  days_inventory_proxy Portfolio
# 185                     NaN                  0.00      Weak
# 120                    0.00              2,670.00      Weak
# 121                    0.00              3,540.00      Weak
# 122                     NaN                  0.00      Weak
# 184                     NaN                  0.00      Weak
# 180                     NaN                  0.00      Weak
# 127                     NaN                  0.00      Weak
# 181                     NaN                  0.00      Weak
# 164                     NaN                  0.00      Weak
# 167                     NaN                  0.00      Weak

# %% [markdown]
# ### Nhận xét
#
# Portfolio Matrix cho phép đánh giá đồng thời khả năng tạo doanh thu và khả năng sinh lợi của từng sản phẩm.
#
# - **Star**: Doanh thu cao, biên lợi nhuận cao. Đây là nhóm sản phẩm chiến lược cần tiếp tục đầu tư và duy trì.
# - **Volume-Low Margin**: Doanh thu cao nhưng biên lợi nhuận thấp. Nhóm này cần xem xét tối ưu giá bán, chi phí hoặc chính sách giảm giá.
# - **Niche-High Margin**: Doanh thu chưa cao nhưng mang lại biên lợi nhuận tốt. Đây là nhóm có tiềm năng mở rộng thông qua marketing hoặc mở rộng thị trường.
# - **Weak**: Doanh thu và biên lợi nhuận đều thấp. Doanh nghiệp cần đánh giá lại chiến lược kinh doanh, cân nhắc giảm tồn kho hoặc loại bỏ khỏi danh mục nếu hiệu quả không được cải thiện.

# %% [markdown]
# 5.3 ABC Analysis
# Mục tiêu
#
# - Xếp hạng sản phẩm theo:
#
#     + Revenue
#     + Gross Profit

# %%
# ABC theo Revenue
abc_revenue = (
    product_profitability
    .sort_values("Revenue", ascending=False)
    .reset_index(drop=True)
)

abc_revenue.head()
# Out:
#    product_key             product_name category_name subcategory_name  \
# 0           21   Mountain-200 Black, 38         Bikes   Mountain Bikes
# 1           20   Mountain-200 Black, 42         Bikes   Mountain Bikes
# 2           24  Mountain-200 Silver, 38         Bikes   Mountain Bikes
# 3           23  Mountain-200 Silver, 42         Bikes   Mountain Bikes
# 4           22  Mountain-200 Silver, 46         Bikes   Mountain Bikes
#
#        Revenue         COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 0 4,400,592.80 3,727,148.33    673,444.47        2977   1,684.97
# 1 4,009,494.76 3,335,278.18    674,216.58        2664   1,710.52
# 2 3,693,678.03 3,029,893.08    663,784.94        2394   1,735.39
# 3 3,438,478.86 2,827,393.96    611,084.90        2234   1,724.51
# 4 3,434,256.94 2,804,612.81    629,644.13        2216   1,728.27
#
#    Avg_Discount  Gross_Margin
# 0          0.00          0.15
# 1          0.00          0.17
# 2          0.00          0.18
# 3          0.00          0.18
# 4          0.00          0.18

# %%
# TÍnh tỷ trọng doanh thu
abc_revenue["Revenue_%"] = (
    abc_revenue["Revenue"]
    / abc_revenue["Revenue"].sum()
)

# %%
# Cumulative Revenue
abc_revenue["Cum_Revenue_%"] = (
    abc_revenue["Revenue_%"]
    .cumsum()
)

# %%
# Phân loại ABC
# Nhóm             Điều kiện
# A                ≤80%
# B                80–95%
# C                >95%

def classify_abc(x):

    if x <= 0.80:
        return "A"

    elif x <= 0.95:
        return "B"

    else:
        return "C"
    
# Áp dụng
abc_revenue["ABC_Revenue"] = (
    abc_revenue["Cum_Revenue_%"]
    .apply(classify_abc)
)

# %%
# Kiểm tra
abc_revenue.head(20)
# Out:
#     product_key             product_name category_name subcategory_name  \
# 0            21   Mountain-200 Black, 38         Bikes   Mountain Bikes
# 1            20   Mountain-200 Black, 42         Bikes   Mountain Bikes
# 2            24  Mountain-200 Silver, 38         Bikes   Mountain Bikes
# 3            23  Mountain-200 Silver, 42         Bikes   Mountain Bikes
# 4            22  Mountain-200 Silver, 46         Bikes   Mountain Bikes
# 5            19   Mountain-200 Black, 46         Bikes   Mountain Bikes
# 6            49       Road-250 Black, 44         Bikes       Road Bikes
# 7            48       Road-250 Black, 48         Bikes       Road Bikes
# 8            47       Road-250 Black, 52         Bikes       Road Bikes
# 9            71         Road-150 Red, 56         Bikes       Road Bikes
# 10           37    Road-350-W Yellow, 48         Bikes       Road Bikes
# 11           75         Road-150 Red, 62         Bikes       Road Bikes
# 12           81    Touring-1000 Blue, 60         Bikes    Touring Bikes
# 13           40    Road-350-W Yellow, 40         Bikes       Road Bikes
# 14           50         Road-250 Red, 58         Bikes       Road Bikes
# 15           84    Touring-1000 Blue, 46         Bikes    Touring Bikes
# 16           73         Road-150 Red, 48         Bikes       Road Bikes
# 17           93  Touring-1000 Yellow, 60         Bikes    Touring Bikes
# 18           46       Road-250 Black, 58         Bikes       Road Bikes
# 19           53         Road-250 Red, 44         Bikes       Road Bikes
#
#         Revenue         COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 0  4,400,592.80 3,727,148.33    673,444.47        2977   1,684.97
# 1  4,009,494.76 3,335,278.18    674,216.58        2664   1,710.52
# 2  3,693,678.03 3,029,893.08    663,784.94        2394   1,735.39
# 3  3,438,478.86 2,827,393.96    611,084.90        2234   1,724.51
# 4  3,434,256.94 2,804,612.81    629,644.13        2216   1,728.27
# 5  3,309,673.22 2,642,932.52    666,740.69        2111   1,713.22
# 6  2,516,857.31 2,553,224.45    -36,367.14        1642   1,757.83
# 7  2,347,655.95 2,329,311.95     18,344.00        1498   1,725.61
# 8  2,012,447.77 1,935,910.14     76,537.64        1245   1,776.28
# 9  1,847,818.63 1,441,739.35    406,079.28         664   2,907.66
# 10 1,774,883.56 1,755,831.22     19,052.34        1622   1,296.69
# 11 1,769,096.69 1,302,776.52    466,320.17         600   2,954.09
# 12 1,721,242.51 1,659,770.45     61,472.07        1120   1,763.96
# 13 1,657,198.18 1,598,867.27     58,330.91        1477   1,304.43
# 14 1,587,008.18 1,470,980.71    116,027.47         946   1,835.35
# 15 1,586,953.57 1,484,901.78    102,051.80        1002   1,811.90
# 16 1,540,803.06 1,070,448.04    470,355.02         493   3,064.47
# 17 1,518,133.10 1,650,878.82   -132,745.72        1114   1,693.30
# 18 1,506,377.63 1,415,002.59     91,375.04         910   1,811.03
# 19 1,448,122.48 1,359,313.83     88,808.65         895   1,839.64
#
#     Avg_Discount  Gross_Margin  Revenue_%  Cum_Revenue_% ABC_Revenue
# 0           0.00          0.15       0.04           0.04           A
# 1           0.00          0.17       0.04           0.08           A
# 2           0.00          0.18       0.03           0.11           A
# 3           0.00          0.18       0.03           0.14           A
# 4           0.00          0.18       0.03           0.17           A
# 5           0.00          0.20       0.03           0.20           A
# 6           0.00         -0.01       0.02           0.23           A
# 7           0.00          0.01       0.02           0.25           A
# 8           0.00          0.04       0.02           0.27           A
# 9           0.00          0.22       0.02           0.28           A
# 10          0.00          0.01       0.02           0.30           A
# 11          0.00          0.26       0.02           0.31           A
# 12          0.00          0.04       0.02           0.33           A
# 13          0.00          0.04       0.02           0.35           A
# 14          0.00          0.07       0.01           0.36           A
# 15          0.00          0.06       0.01           0.37           A
# 16          0.00          0.31       0.01           0.39           A
# 17          0.03         -0.09       0.01           0.40           A
# 18          0.00          0.06       0.01           0.42           A
# 19          0.00          0.06       0.01           0.43           A

# %%
# Thống kê
abc_revenue.groupby("ABC_Revenue").agg(

    Products=("product_key","count"),

    Revenue=("Revenue","sum"),

    Gross_Profit=("Gross_Profit","sum")

)
# Out:
#              Products       Revenue  Gross_Profit
# ABC_Revenue
# A                  63 87,741,348.82  7,538,210.58
# B                  66 16,529,057.18    863,903.25
# C                 137  5,575,975.40    969,789.79

# %%
# Pareto Revenue
fig, ax1 = plt.subplots(figsize=(14,6))

ax1.bar(
    abc_revenue["product_name"],
    abc_revenue["Revenue"]
)

ax1.set_ylabel("Revenue")

ax2 = ax1.twinx()

ax2.plot(
    abc_revenue["Cum_Revenue_%"].values,
    color="red",
    linewidth=2
)

ax2.set_ylabel("Cumulative %")

ax2.axhline(
    0.80,
    linestyle="--",
    color="green"
)

ax2.axhline(
    0.95,
    linestyle="--",
    color="orange"
)

plt.xticks([])

plt.title("Pareto Analysis - Revenue")

plt.show()

# %%
# ABC theo Gross Profit
abc_profit = (
    product_profitability
    .sort_values(
        "Gross_Profit",
        ascending=False
    )
    .reset_index(drop=True)
)

abc_profit["Profit_%"] = (
    abc_profit["Gross_Profit"]
    /
    abc_profit["Gross_Profit"].sum()
)

abc_profit["Cum_Profit_%"] = (
    abc_profit["Profit_%"]
    .cumsum()
)

abc_profit["ABC_Profit"] = (
    abc_profit["Cum_Profit_%"]
    .apply(classify_abc)
)

# %%
# Pareto Profit
fig, ax1 = plt.subplots(figsize=(14,6))

ax1.bar(
    abc_profit["product_name"],
    abc_profit["Gross_Profit"]
)

ax2 = ax1.twinx()

ax2.plot(
    abc_profit["Cum_Profit_%"],
    color="red"
)

ax2.axhline(
    0.80,
    linestyle="--"
)

ax2.axhline(
    0.95,
    linestyle="--"
)

plt.xticks([])

plt.title("Pareto Analysis - Gross Profit")

plt.show()

# %%
# So sánh Revenue và Profit
abc_compare = (
    abc_revenue[
        [
            "product_key",
            "ABC_Revenue"
        ]
    ]
    .merge(

        abc_profit[
            [
                "product_key",
                "ABC_Profit"
            ]
        ],

        on="product_key"
    )
)

abc_compare.head()
# Out:
#    product_key ABC_Revenue ABC_Profit
# 0           21           A          A
# 1           20           A          A
# 2           24           A          A
# 3           23           A          A
# 4           22           A          A

# %%
# Cross Table
cross = pd.crosstab(
    abc_compare["ABC_Revenue"],
    abc_compare["ABC_Profit"]
)

plt.figure(figsize=(6,4))

sns.heatmap(
    cross,
    annot=True,
    fmt="d",
    cmap="YlGnBu"
)

plt.title("ABC Revenue vs ABC Profit")

plt.xlabel("ABC Profit")

plt.ylabel("ABC Revenue")

plt.show()

# %%
# Danh sách sản phẩm trọng yếu
important_products = (
    abc_revenue[
        abc_revenue["ABC_Revenue"]=="A"
    ]
)

important_products.head(20)
# Out:
#     product_key             product_name category_name subcategory_name  \
# 0            21   Mountain-200 Black, 38         Bikes   Mountain Bikes
# 1            20   Mountain-200 Black, 42         Bikes   Mountain Bikes
# 2            24  Mountain-200 Silver, 38         Bikes   Mountain Bikes
# 3            23  Mountain-200 Silver, 42         Bikes   Mountain Bikes
# 4            22  Mountain-200 Silver, 46         Bikes   Mountain Bikes
# 5            19   Mountain-200 Black, 46         Bikes   Mountain Bikes
# 6            49       Road-250 Black, 44         Bikes       Road Bikes
# 7            48       Road-250 Black, 48         Bikes       Road Bikes
# 8            47       Road-250 Black, 52         Bikes       Road Bikes
# 9            71         Road-150 Red, 56         Bikes       Road Bikes
# 10           37    Road-350-W Yellow, 48         Bikes       Road Bikes
# 11           75         Road-150 Red, 62         Bikes       Road Bikes
# 12           81    Touring-1000 Blue, 60         Bikes    Touring Bikes
# 13           40    Road-350-W Yellow, 40         Bikes       Road Bikes
# 14           50         Road-250 Red, 58         Bikes       Road Bikes
# 15           84    Touring-1000 Blue, 46         Bikes    Touring Bikes
# 16           73         Road-150 Red, 48         Bikes       Road Bikes
# 17           93  Touring-1000 Yellow, 60         Bikes    Touring Bikes
# 18           46       Road-250 Black, 58         Bikes       Road Bikes
# 19           53         Road-250 Red, 44         Bikes       Road Bikes
#
#         Revenue         COGS  Gross_Profit  Units_Sold  Avg_Price  \
# 0  4,400,592.80 3,727,148.33    673,444.47        2977   1,684.97
# 1  4,009,494.76 3,335,278.18    674,216.58        2664   1,710.52
# 2  3,693,678.03 3,029,893.08    663,784.94        2394   1,735.39
# 3  3,438,478.86 2,827,393.96    611,084.90        2234   1,724.51
# 4  3,434,256.94 2,804,612.81    629,644.13        2216   1,728.27
# 5  3,309,673.22 2,642,932.52    666,740.69        2111   1,713.22
# 6  2,516,857.31 2,553,224.45    -36,367.14        1642   1,757.83
# 7  2,347,655.95 2,329,311.95     18,344.00        1498   1,725.61
# 8  2,012,447.77 1,935,910.14     76,537.64        1245   1,776.28
# 9  1,847,818.63 1,441,739.35    406,079.28         664   2,907.66
# 10 1,774,883.56 1,755,831.22     19,052.34        1622   1,296.69
# 11 1,769,096.69 1,302,776.52    466,320.17         600   2,954.09
# 12 1,721,242.51 1,659,770.45     61,472.07        1120   1,763.96
# 13 1,657,198.18 1,598,867.27     58,330.91        1477   1,304.43
# 14 1,587,008.18 1,470,980.71    116,027.47         946   1,835.35
# 15 1,586,953.57 1,484,901.78    102,051.80        1002   1,811.90
# 16 1,540,803.06 1,070,448.04    470,355.02         493   3,064.47
# 17 1,518,133.10 1,650,878.82   -132,745.72        1114   1,693.30
# 18 1,506,377.63 1,415,002.59     91,375.04         910   1,811.03
# 19 1,448,122.48 1,359,313.83     88,808.65         895   1,839.64
#
#     Avg_Discount  Gross_Margin  Revenue_%  Cum_Revenue_% ABC_Revenue
# 0           0.00          0.15       0.04           0.04           A
# 1           0.00          0.17       0.04           0.08           A
# 2           0.00          0.18       0.03           0.11           A
# 3           0.00          0.18       0.03           0.14           A
# 4           0.00          0.18       0.03           0.17           A
# 5           0.00          0.20       0.03           0.20           A
# 6           0.00         -0.01       0.02           0.23           A
# 7           0.00          0.01       0.02           0.25           A
# 8           0.00          0.04       0.02           0.27           A
# 9           0.00          0.22       0.02           0.28           A
# 10          0.00          0.01       0.02           0.30           A
# 11          0.00          0.26       0.02           0.31           A
# 12          0.00          0.04       0.02           0.33           A
# 13          0.00          0.04       0.02           0.35           A
# 14          0.00          0.07       0.01           0.36           A
# 15          0.00          0.06       0.01           0.37           A
# 16          0.00          0.31       0.01           0.39           A
# 17          0.03         -0.09       0.01           0.40           A
# 18          0.00          0.06       0.01           0.42           A
# 19          0.00          0.06       0.01           0.43           A

# %% [markdown]
# ### Nhận xét
#
# ABC Analysis cho thấy mức độ tập trung doanh thu và lợi nhuận của danh mục sản phẩm.
#
# Nhóm A chỉ chiếm một tỷ lệ nhỏ số lượng sản phẩm nhưng đóng góp khoảng 80% tổng doanh thu hoặc lợi nhuận. Đây là nhóm sản phẩm chiến lược cần được ưu tiên trong quản trị danh mục.
#
# Việc so sánh ABC theo doanh thu và ABC theo lợi nhuận giúp phát hiện các sản phẩm có doanh thu cao nhưng lợi nhuận thấp. Đây là những trường hợp cần phân tích sâu hơn về chi phí, chính sách giá hoặc chương trình giảm giá trong các phần tiếp theo.

# %% [markdown]
# 5.4 Discount Analysis
# - Mục tiêu
#
#     + Đánh giá hiệu quả của chính sách giảm giá.

# %%
discount_nonzero = profit_df[profit_df["avg_discount_rate"] > 0].copy()

discount_nonzero.shape
# Out:
# (1986, 20)

# %%
# Tạo bảng Discount Analysis
discount = (
    discount_nonzero
    .groupby(
        ["product_key", "product_name", "category_name"],
        as_index=False
    )
    .agg(
        Revenue=("revenue", "sum"),
        Units=("quantity", "sum"),
        Gross_Profit=("gross_profit", "sum"),
        Gross_Margin=("gross_margin", "mean"),
        Discount=("avg_discount_rate", "mean")
    )
)

discount.head()
# Out:
#    product_key             product_name category_name  Revenue  Units  \
# 0            6  Mountain-500 Silver, 52         Bikes 6,034.09     89
# 1            7  Mountain-500 Silver, 48         Bikes 5,830.70     86
# 2            8  Mountain-500 Silver, 44         Bikes 3,864.53     57
# 3            9  Mountain-500 Silver, 42         Bikes 5,762.90     85
# 4           10  Mountain-500 Silver, 40         Bikes 4,406.92     65
#
#    Gross_Profit  Gross_Margin  Discount
# 0    -21,397.30         -3.55      0.40
# 1    -20,676.04         -3.55      0.40
# 2    -13,703.89         -3.55      0.40
# 3    -20,435.62         -3.55      0.40
# 4    -15,627.24         -3.55      0.40

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    discount["Discount"],
    discount["Units"],
    alpha=0.7
)

plt.xlabel("Average Discount Rate")
plt.ylabel("Units Sold")
plt.title("Discount Rate vs Units Sold")

plt.show()

# %%
# Tính Growth
# Doanh thu theo từng tháng
growth = (
    profit_df
    .groupby(["product_key", "month_key"], as_index=False)
    .agg(Revenue=("revenue", "sum"))
)

growth["Growth"] = (
    growth.groupby("product_key")["Revenue"]
    .pct_change()
)

growth_summary = (
    growth.groupby("product_key", as_index=False)
    .agg(Avg_Growth=("Growth", "mean"))
)

discount = discount.merge(
    growth_summary,
    on="product_key",
    how="left"
)

discount_cut = discount["Discount"].median()
growth_cut = 0

ineffective_discount = discount[
    (discount["Discount"] >= discount_cut) &
    (discount["Avg_Growth"] <= growth_cut)
].sort_values("Discount", ascending=False)

ineffective_discount.head(20)
# Out:
#      product_key                     product_name category_name    Revenue  \
# 0              6          Mountain-500 Silver, 52         Bikes   6,034.09
# 3              9          Mountain-500 Silver, 42         Bikes   5,762.90
# 108          250       Women's Mountain Shorts, L      Clothing  86,759.16
# 118          266                  Classic Vest, S      Clothing 115,821.57
# 112          257                  Racing Socks, L      Clothing   7,683.98
# 102          242  Short-Sleeve Classic Jersey, XL      Clothing  79,755.52
# 28            40            Road-350-W Yellow, 40         Bikes 350,837.86
# 25            34               Road-750 Black, 48         Bikes  68,207.76
# 119          267              Hitch Rack - 4-Bike   Accessories 113,352.16
# 117          265                  Classic Vest, M      Clothing  39,018.80
# 103          243   Short-Sleeve Classic Jersey, L      Clothing  40,023.14
# 121          272            Bike Wash - Dissolver   Accessories   6,165.56
# 26            37            Road-350-W Yellow, 48         Bikes 542,346.20
#
#      Units  Gross_Profit  Gross_Margin  Discount  Avg_Growth
# 0       89    -21,397.30         -3.55      0.40       -0.04
# 3       85    -20,435.62         -3.55      0.40       -0.02
# 108   2295     26,684.55          0.31      0.02       -0.02
# 118   3294     37,592.36          0.33      0.02       -0.03
# 112   1522      2,566.56          0.34      0.01       -0.02
# 102   2612    -28,831.33         -0.36      0.01       -0.07
# 28     361    -39,948.25         -0.12      0.01       -0.01
# 25     224     -8,769.75         -0.13      0.01       -0.02
# 119   1666     38,582.08          0.34      0.01       -0.01
# 117   1072     13,559.87          0.35      0.01       -0.04
# 103   1293    -13,729.84         -0.35      0.01       -0.07
# 121   1358      2,127.82          0.35      0.01       -0.02
# 26     569    -73,601.99         -0.13      0.01       -0.01

# %%
# Discount Distribution
plt.figure(figsize=(8,5))

plt.hist(
    discount["Discount"],
    bins=20
)

plt.title("Distribution of Average Discount")

plt.xlabel("Discount Rate")

plt.ylabel("Products")

plt.show()

# %%
# Scatter Discount vs Units Sold
# Ý nghĩa
# Nếu Discount tăng
# ↓
# Units cũng tăng
# ↓
# Promotion hiệu quả.
# Nếu không có xu hướng
# ↓
# Discount đang lãng phí.
plt.figure(figsize=(10,6))

plt.scatter(

    discount["Discount"],

    discount["Units"],

    alpha=0.7

)

plt.xlabel("Average Discount Rate")

plt.ylabel("Units Sold")

plt.title("Discount Rate vs Units Sold")

plt.show()

# %%
# Discount vs Revenue Growth
plt.figure(figsize=(10,6))

plt.scatter(

    discount["Discount"],

    discount["Avg_Growth"],

    alpha=0.7

)

plt.xlabel("Average Discount Rate")

plt.ylabel("Average Revenue Growth")

plt.title("Discount Rate vs Revenue Growth")

plt.axhline(0,linestyle="--")

plt.show()

# %%
# Discount vs Margin
plt.figure(figsize=(10,6))

plt.scatter(

    discount["Discount"],

    discount["Gross_Margin"],

    alpha=0.7

)

plt.xlabel("Discount Rate")

plt.ylabel("Gross Margin")

plt.title("Discount Rate vs Gross Margin")

plt.show()

# %%
# Xác định Discount không hiệu quả
# Định nghĩa:
# Discount cao
# Growth thấp
# ↓
# Không hiệu quả.
discount["Discount"].describe()
discount_cut = discount["Discount"].median()

growth_cut = 0

ineffective_discount = discount[

    (discount["Discount"]>=discount_cut)

    &

    (discount["Avg_Growth"]<=growth_cut)

]

ineffective_discount.sort_values(

    "Discount",

    ascending=False

).head(20)
# Out:
#      product_key                     product_name category_name    Revenue  \
# 0              6          Mountain-500 Silver, 52         Bikes   6,034.09
# 3              9          Mountain-500 Silver, 42         Bikes   5,762.90
# 108          250       Women's Mountain Shorts, L      Clothing  86,759.16
# 118          266                  Classic Vest, S      Clothing 115,821.57
# 112          257                  Racing Socks, L      Clothing   7,683.98
# 102          242  Short-Sleeve Classic Jersey, XL      Clothing  79,755.52
# 28            40            Road-350-W Yellow, 40         Bikes 350,837.86
# 25            34               Road-750 Black, 48         Bikes  68,207.76
# 119          267              Hitch Rack - 4-Bike   Accessories 113,352.16
# 117          265                  Classic Vest, M      Clothing  39,018.80
# 103          243   Short-Sleeve Classic Jersey, L      Clothing  40,023.14
# 121          272            Bike Wash - Dissolver   Accessories   6,165.56
# 26            37            Road-350-W Yellow, 48         Bikes 542,346.20
#
#      Units  Gross_Profit  Gross_Margin  Discount  Avg_Growth
# 0       89    -21,397.30         -3.55      0.40       -0.04
# 3       85    -20,435.62         -3.55      0.40       -0.02
# 108   2295     26,684.55          0.31      0.02       -0.02
# 118   3294     37,592.36          0.33      0.02       -0.03
# 112   1522      2,566.56          0.34      0.01       -0.02
# 102   2612    -28,831.33         -0.36      0.01       -0.07
# 28     361    -39,948.25         -0.12      0.01       -0.01
# 25     224     -8,769.75         -0.13      0.01       -0.02
# 119   1666     38,582.08          0.34      0.01       -0.01
# 117   1072     13,559.87          0.35      0.01       -0.04
# 103   1293    -13,729.84         -0.35      0.01       -0.07
# 121   1358      2,127.82          0.35      0.01       -0.02
# 26     569    -73,601.99         -0.13      0.01       -0.01

# %%
# Discount hiệu quả
effective_discount = discount[

    (discount["Discount"]>=discount_cut)

    &

    (discount["Avg_Growth"]>growth_cut)

]

effective_discount.head(20)
# Out:
#     product_key               product_name category_name    Revenue  Units  \
# 1             7    Mountain-500 Silver, 48         Bikes   5,830.70     86
# 2             8    Mountain-500 Silver, 44         Bikes   3,864.53     57
# 4            10    Mountain-500 Silver, 40         Bikes   4,406.92     65
# 5            11  Mountain-400-W Silver, 46         Bikes   4,811.16     11
# 11           20     Mountain-200 Black, 42         Bikes 249,743.82    201
# 14           23    Mountain-200 Silver, 42         Bikes 146,595.33    117
# 16           25     Mountain-100 Black, 48         Bikes  33,454.59     61
# 17           26     Mountain-100 Black, 44         Bikes 102,256.12     94
# 18           27     Mountain-100 Black, 42         Bikes  68,076.25     78
# 19           28     Mountain-100 Black, 38         Bikes 156,050.76    130
# 20           29    Mountain-100 Silver, 48         Bikes  22,099.94     40
# 21           30    Mountain-100 Silver, 44         Bikes 120,373.59     96
# 22           31    Mountain-100 Silver, 42         Bikes  70,618.13     74
# 23           32    Mountain-100 Silver, 38         Bikes  35,912.39     65
# 27           39      Road-350-W Yellow, 42         Bikes  55,927.02     58
# 29           41      Road-550-W Yellow, 48         Bikes  58,841.00     99
# 31           45      Road-550-W Yellow, 38         Bikes  23,375.33     39
# 32           48         Road-250 Black, 48         Bikes  36,770.43     28
# 35           53           Road-250 Red, 44         Bikes  70,073.08     51
# 41           62           Road-650 Red, 44         Bikes 263,766.78    778
#
#     Gross_Profit  Gross_Margin  Discount  Avg_Growth
# 1     -20,676.04         -3.55      0.40        0.09
# 2     -13,703.89         -3.55      0.40        0.09
# 4     -15,627.24         -3.55      0.40        0.06
# 5         193.60          0.04      0.02        0.10
# 11     -1,904.42          0.00      0.01        0.07
# 14     -1,482.15         -0.01      0.01        0.06
# 16    -82,329.17         -2.46      0.35        0.43
# 17    -76,164.75         -1.75      0.25        0.29
# 18    -79,975.11         -2.11      0.30        0.46
# 19    -90,701.51         -1.63      0.24        0.27
# 20    -54,386.24         -2.46      0.35        0.56
# 21    -63,193.24         -1.84      0.26        0.30
# 22    -70,881.29         -2.05      0.29        1.37
# 23    -88,377.64         -2.46      0.35        0.63
# 27     -6,858.56         -0.12      0.01        0.01
# 29    -11,753.90         -0.20      0.02        0.01
# 31     -4,434.78         -0.21      0.02        0.03
# 32     -6,768.11         -0.17      0.01        0.05
# 35     -7,385.03         -0.12      0.02        0.02
# 41   -114,890.95         -1.05      0.16        0.08

# %%
# Bubble Chart
plt.figure(figsize=(12,8))

scatter = plt.scatter(

    discount["Discount"],

    discount["Avg_Growth"],

    s=discount["Revenue"]/discount["Revenue"].max()*800,

    c=discount["Gross_Margin"],

    cmap="RdYlGn",

    alpha=0.7

)

plt.colorbar(scatter,label="Gross Margin")

plt.xlabel("Discount Rate")

plt.ylabel("Revenue Growth")

plt.title("Discount Effectiveness Analysis")

plt.axhline(0,linestyle="--")

plt.show()

# %% [markdown]
# ### Nhận xét
#
# Phân tích discount cho thấy phần lớn giao dịch không áp dụng giảm giá, với khoảng 94% dòng dữ liệu có discount rate bằng 0. Do đó, discount không phải là chiến lược bán hàng phổ biến trong tập dữ liệu này. Phần phân tích được tập trung vào các sản phẩm/tháng có discount rate lớn hơn 0 nhằm đánh giá hiệu quả của các trường hợp có khuyến mãi.
#
# Các sản phẩm có discount cao nhưng tăng trưởng doanh thu thấp hoặc âm được xem là nhóm discount không hiệu quả. Đây là nhóm cần được xem xét lại về chính sách promotion, vì giảm giá có thể làm giảm biên lợi nhuận nhưng không tạo ra đủ tăng trưởng về doanh thu hoặc sản lượng bán.

# %% [markdown]
# 5.5 Inventory Analysis
#
# - Mục tiêu
#
# - Đánh giá hiệu quả quản lý tồn kho của từng sản phẩm thông qua:
#
#     + Inventory Turnover
#     + Days Inventory
#     + Gross Margin

# %%
# Đọc mart Inventory Risk
inventory = pd.read_sql("""
SELECT *
FROM mart.mart_inventory_risk;
""", engine)

inventory.head()
# Out:
#    product_key             product_name category_name subcategory_name  \
# 0          384               Lock Nut 7          None             None
# 1          351           Lock Washer 11          None             None
# 2          116          Rear Derailleur    Components      Derailleurs
# 3           87  Touring-3000 Yellow, 54         Bikes    Touring Bikes
# 4          477            Flat Washer 8          None             None
#
#    units_sold    revenue       cogs  gross_profit  gross_margin  \
# 0           0       0.00       0.00          0.00           NaN
# 1           0       0.00       0.00          0.00           NaN
# 2         353  25,725.23  19,036.65      6,688.57          0.26
# 3         453 196,809.98 209,034.49    -12,224.52         -0.06
# 4           0       0.00       0.00          0.00           NaN
#
#    current_inventory_qty  avg_inventory_qty  max_inventory_qty  \
# 0                   1661             553.67                630
# 1                   1743             581.00                640
# 2                    847             282.33                355
# 3                    162              81.00                126
# 4                    896             298.67                332
#
#    min_inventory_qty  inventory_records  inventory_turnover_qty  \
# 0                507                  3                    0.00
# 1                518                  3                    0.00
# 2                155                  3                    0.00
# 3                 36                  2                    2.00
# 4                246                  3                    0.00
#
#    days_inventory_proxy       inventory_risk_status
# 0                   NaN  No Demand - Overstock Risk
# 1                   NaN  No Demand - Overstock Risk
# 2                 60.00                 Slow Moving
# 3                  0.00                     Healthy
# 4                   NaN  No Demand - Overstock Risk

# %%
# Kiểm tra dữ liệu
inventory.info()
inventory.describe().T
inventory.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_key             488 non-null    int64
#  1   product_name            488 non-null    object
#  2   category_name           279 non-null    object
#  3   subcategory_name        279 non-null    object
#  4   units_sold              488 non-null    int64
#  5   revenue                 488 non-null    float64
#  6   cogs                    488 non-null    float64
#  7   gross_profit            488 non-null    float64
#  8   gross_margin            266 non-null    float64
#  9   current_inventory_qty   488 non-null    int64
#  10  avg_inventory_qty       488 non-null    float64
#  11  max_inventory_qty       488 non-null    int64
#  12  min_inventory_qty       488 non-null    int64
#  13  inventory_records       488 non-null    int64
#  14  inventory_turnover_qty  428 non-null    float64
#  15  days_inventory_proxy    266 non-null    float64
#  16  inventory_risk_status   488 non-null    object
# dtypes: float64(7), int64(6), object(4)
# memory usage: 64.9+ KB
# product_key                 0
# product_name                0
# category_name             209
# subcategory_name          209
# units_sold                  0
# revenue                     0
# cogs                        0
# gross_profit                0
# gross_margin              222
# current_inventory_qty       0
# avg_inventory_qty           0
# max_inventory_qty           0
# min_inventory_qty           0
# inventory_records           0
# inventory_turnover_qty     60
# days_inventory_proxy      222
# inventory_risk_status       0
# dtype: int64

# %%
# Phân bố Inventory Status
inventory["inventory_risk_status"].value_counts()

inventory["inventory_risk_status"]\
    .value_counts()\
    .plot(
        kind="bar",
        figsize=(8,5)
    )

plt.title("Distribution of Inventory Risk Status")

plt.ylabel("Products")

plt.show()

# %%
# Inventory Turnover
# Top Inventory Turnover
inventory.sort_values(
    "inventory_turnover_qty",
    ascending=False
)[
[
    "product_name",
    "inventory_turnover_qty",
    "current_inventory_qty",
    "units_sold"
]
].head(20)
# Out:
#                         product_name  inventory_turnover_qty  \
# 8              Bike Wash - Dissolver                   92.00
# 161   Short-Sleeve Classic Jersey, L                   79.00
# 50                 Women's Tights, L                   58.00
# 84   Short-Sleeve Classic Jersey, XL                   53.00
# 56             Half-Finger Gloves, L                   35.00
# 329           Sport-100 Helmet, Blue                   31.00
# 385       Long-Sleeve Logo Jersey, L                   30.00
# 264                     AWC Logo Cap                   28.00
# 30             Water Bottle - 30 oz.                   27.00
# 344          Hydration Pack - 70 oz.                   25.00
# 87                   Classic Vest, S                   23.00
# 29             Full-Finger Gloves, L                   23.00
# 326              Patch Kit/8 Patches                   21.00
# 228            Sport-100 Helmet, Red                   21.00
# 397       Long-Sleeve Logo Jersey, M                   20.00
# 230            Full-Finger Gloves, M                   20.00
# 384          Sport-100 Helmet, Black                   20.00
# 5              Fender Set - Mountain                   19.00
# 188           Mountain-200 Black, 42                   18.00
# 401          Mountain-200 Silver, 38                   17.00
#
#      current_inventory_qty  units_sold
# 8                       36        3319
# 161                     36        2848
# 50                      36        2123
# 84                      72        3864
# 56                      36        1276
# 329                    216        6743
# 385                    216        6592
# 264                    288        8311
# 30                     252        6815
# 344                    108        2761
# 87                     180        4247
# 29                     144        3378
# 326                    180        3865
# 228                    288        6266
# 397                    180        3636
# 230                    108        2206
# 384                    324        6532
# 5                      108        2121
# 188                    148        2664
# 401                    137        2394

# %%
# Bottom Inventory Turnover
inventory.sort_values(
    "inventory_turnover_qty"
)[
[
    "product_name",
    "inventory_turnover_qty",
    "current_inventory_qty",
    "units_sold"
]
].head(20)
# Out:
#                       product_name  inventory_turnover_qty  \
# 0                       Lock Nut 7                    0.00
# 256  LL Mountain Frame - Black, 40                    0.00
# 251        Internal Lock Washer 10                    0.00
# 250                    HL Crankset                    0.00
# 249              LL Bottom Bracket                    0.00
# 247           Thin-Jam Lock Nut 16                    0.00
# 245         External Lock Washer 2                    0.00
# 243                Adjustable Race                    0.00
# 257            Thin-Jam Hex Nut 11                    0.00
# 242                    LL Crankset                    0.00
# 240                    Lock Nut 11                    0.00
# 239                    Metal Bar 2                    0.00
# 238                    HL Road Rim                    0.00
# 237              Metal Tread Plate                    0.00
# 236                    Lock Nut 12                    0.00
# 235                HL Mountain Rim                    0.00
# 233                      Hex Nut 5                    0.00
# 241               Front Derailleur                    0.00
# 231          Front Derailleur Cage                    0.00
# 258          HL Touring Handlebars                    0.00
#
#      current_inventory_qty  units_sold
# 0                     1661           0
# 256                    719           8
# 251                    919           0
# 250                    923         613
# 249                    814         378
# 247                   1608           0
# 245                   1614           0
# 243                   1085           0
# 257                    916           0
# 242                    885         426
# 240                   1556           0
# 239                   1687           0
# 238                    615           0
# 237                   1837           0
# 236                   1589           0
# 235                   1247           0
# 233                    925           0
# 241                    853         813
# 231                    605           0
# 258                    792         220

# %%
# Days Inventory
# Top tồn kho lâu nhất
inventory.sort_values(
    "days_inventory_proxy",
    ascending=False
)[
[
    "product_name",
    "days_inventory_proxy",
    "current_inventory_qty",
    "units_sold"
]
].head(20)
# Out:
#                          product_name  days_inventory_proxy  \
# 60   ML Mountain Frame-W - Silver, 38              3,540.00
# 67                LL Road Seat/Saddle              2,700.00
# 256     LL Mountain Frame - Black, 40              2,670.00
# 369             LL Touring Handlebars                420.00
# 121                ML Road Rear Wheel                390.00
# 61                        ML Crankset                390.00
# 178            LL Touring Seat/Saddle                240.00
# 408                        LL Headset                240.00
# 126                HL Road Rear Wheel                210.00
# 308                     Touring Pedal                180.00
# 266                           LL Fork                120.00
# 226            ML Touring Seat/Saddle                120.00
# 207           HL Mountain Front Wheel                 90.00
# 362               HL Road Seat/Saddle                 90.00
# 258             HL Touring Handlebars                 90.00
# 341                LL Road Handlebars                 90.00
# 68                         HL Headset                 90.00
# 171           ML Mountain Front Wheel                 90.00
# 194                       Rear Brakes                 60.00
# 402            HL Touring Seat/Saddle                 60.00
#
#      current_inventory_qty  units_sold
# 60                     826           7
# 67                     906          10
# 256                    719           8
# 369                    802          56
# 121                    837          64
# 61                     905          68
# 178                    801          91
# 408                    761          95
# 126                    716          94
# 308                    885         147
# 266                    863         190
# 226                    402          84
# 207                    831         222
# 362                    467         134
# 258                    792         220
# 341                    831         213
# 68                     782         255
# 171                    818         266
# 194                    723         246
# 402                    989         426

# %%
# Margin × Inventory

# Ý nghĩa:

# Góc trên trái

# ↓

# Margin cao

# ↓

# Inventory thấp

# ↓

# Healthy

# Góc dưới phải

# ↓

# Margin thấp

# ↓

# Inventory cao

# ↓

# Inventory Risk

plt.figure(figsize=(12,7))

scatter = plt.scatter(

    inventory["days_inventory_proxy"],

    inventory["gross_margin"],

    s=inventory["current_inventory_qty"]/inventory["current_inventory_qty"].max()*1000,

    alpha=0.7

)

plt.xlabel("Days Inventory")

plt.ylabel("Gross Margin")

plt.title("Inventory Risk Matrix")

plt.show()

# %%
# Slow Moving
slow_moving = inventory[

    inventory["inventory_risk_status"]=="Slow Moving"

]

slow_moving.sort_values(

    "current_inventory_qty",

    ascending=False

).head(20)
# Out:
#      product_key                      product_name category_name  \
# 402          191            HL Touring Seat/Saddle    Components
# 192          106                 HL Bottom Bracket    Components
# 250          112                       HL Crankset    Components
# 166          152                     HL Road Pedal    Components
# 67           196               LL Road Seat/Saddle    Components
# 61           113                       ML Crankset    Components
# 55           117                           HL Fork    Components
# 308          151                     Touring Pedal    Components
# 242          114                       LL Crankset    Components
# 266          119                           LL Fork    Components
# 241          115                  Front Derailleur    Components
# 2            116                   Rear Derailleur    Components
# 49           103            HL Mountain Handlebars    Components
# 121          220                ML Road Rear Wheel    Components
# 164          142     HL Mountain Frame - Black, 38    Components
# 341          102                LL Road Handlebars    Components
# 207          229           HL Mountain Front Wheel    Components
# 60           125  ML Mountain Frame-W - Silver, 38    Components
# 171          230           ML Mountain Front Wheel    Components
# 249          108                 LL Bottom Bracket    Components
#
#     subcategory_name  units_sold    revenue       cogs  gross_profit  \
# 402          Saddles         426  13,454.78   9,956.56      3,498.23
# 192  Bottom Brackets         543  39,581.44  29,290.29     10,291.15
# 250        Cranksets         613 148,622.58 110,226.96     38,395.62
# 166           Pedals         676  32,849.54  24,308.69      8,540.85
# 67           Saddles          10     162.72     120.41         42.31
# 61         Cranksets          68  10,464.79   7,743.95      2,720.84
# 55             Forks         444  61,034.61  45,240.76     15,793.85
# 308           Pedals         147   7,143.32   5,286.06      1,857.26
# 242        Cranksets         426  44,855.24  33,192.90     11,662.35
# 266            Forks         190  16,897.08  12,503.84      4,393.24
# 241      Derailleurs         813  44,484.27  33,025.36     11,458.91
# 2        Derailleurs         353  25,725.23  19,036.65      6,688.57
# 49        Handlebars         500  34,375.35  26,699.95      7,675.40
# 121           Wheels          64  10,574.78   7,825.34      2,749.45
# 164  Mountain Frames         659 501,788.20 487,028.02     14,760.18
# 341       Handlebars         213   5,422.54   4,212.25      1,210.29
# 207           Wheels         222  39,988.64  29,591.60     10,397.04
# 60   Mountain Frames           7   1,529.18   1,395.63        133.55
# 171           Wheels         266  33,360.39  24,686.69      8,673.70
# 249  Bottom Brackets         378  12,244.93   9,061.26      3,183.67
#
#      gross_margin  current_inventory_qty  avg_inventory_qty  \
# 402          0.26                    989             329.67
# 192          0.26                    970             323.33
# 250          0.26                    923             307.67
# 166          0.26                    906             302.00
# 67           0.26                    906             302.00
# 61           0.26                    905             301.67
# 55           0.26                    901             300.33
# 308          0.26                    885             295.00
# 242          0.26                    885             295.00
# 266          0.26                    863             287.67
# 241          0.26                    853             284.33
# 2            0.26                    847             282.33
# 49           0.22                    840             280.00
# 121          0.26                    837             418.50
# 164          0.03                    834             139.00
# 341          0.22                    831             277.00
# 207          0.26                    831             415.50
# 60           0.09                    826             137.67
# 171          0.26                    818             409.00
# 249          0.26                    814             271.33
#
#      max_inventory_qty  min_inventory_qty  inventory_records  \
# 402                425                276                  3
# 192                475                174                  3
# 250                348                278                  3
# 166                323                267                  3
# 67                 321                283                  3
# 61                 342                272                  3
# 55                 363                252                  3
# 308                388                235                  3
# 242                336                265                  3
# 266                350                240                  3
# 241                347                236                  3
# 2                  355                155                  3
# 49                 310                260                  3
# 121                425                412                  2
# 164                161                107                  6
# 341                307                257                  3
# 207                443                388                  2
# 60                 160                105                  6
# 171                412                406                  2
# 249                358                212                  3
#
#      inventory_turnover_qty  days_inventory_proxy inventory_risk_status
# 402                    0.00                 60.00           Slow Moving
# 192                    0.00                 30.00           Slow Moving
# 250                    0.00                 30.00           Slow Moving
# 166                    0.00                 30.00           Slow Moving
# 67                     0.00              2,700.00           Slow Moving
# 61                     0.00                390.00           Slow Moving
# 55                     0.00                 60.00           Slow Moving
# 308                    0.00                180.00           Slow Moving
# 242                    0.00                 60.00           Slow Moving
# 266                    0.00                120.00           Slow Moving
# 241                    0.00                 30.00           Slow Moving
# 2                      0.00                 60.00           Slow Moving
# 49                     0.00                 30.00           Slow Moving
# 121                    0.00                390.00           Slow Moving
# 164                    0.00                 30.00           Slow Moving
# 341                    0.00                 90.00           Slow Moving
# 207                    0.00                 90.00           Slow Moving
# 60                     0.00              3,540.00           Slow Moving
# 171                    0.00                 90.00           Slow Moving
# 249                    0.00                 60.00           Slow Moving

# %%
# Overstock
overstock = inventory[

    inventory["inventory_risk_status"]=="No Demand - Overstock Risk"

]

overstock.head(20)
# Out:
#     product_key               product_name category_name subcategory_name  \
# 0           384                 Lock Nut 7          None             None
# 1           351             Lock Washer 11          None             None
# 4           477              Flat Washer 8          None             None
# 6           394       Thin-Jam Lock Nut 13          None             None
# 10          350                Metal Angle          None             None
# 11          314      ML Road Seat Assembly          None             None
# 12          386                Lock Nut 16          None             None
# 13          431                  Hex Nut 4          None             None
# 14          278  Headlights - Weatherproof   Accessories           Lights
# 15          426                     LL Hub          None             None
# 16          424               Keyed Washer          None             None
# 17          406     Internal Lock Washer 8          None             None
# 18          364            Lower Head Race          None             None
# 19          433                 Hex Nut 14          None             None
# 20          491                    Decal 1          None             None
# 21          462        Thin-Jam Hex Nut 16          None             None
# 22          299                  Seat Tube          None             None
# 23          309            LL Spindle/Axle          None             None
# 24          345              Metal Plate 3          None             None
# 26          436                 Hex Nut 20          None             None
#
#     units_sold  revenue  cogs  gross_profit  gross_margin  \
# 0            0     0.00  0.00          0.00           NaN
# 1            0     0.00  0.00          0.00           NaN
# 4            0     0.00  0.00          0.00           NaN
# 6            0     0.00  0.00          0.00           NaN
# 10           0     0.00  0.00          0.00           NaN
# 11           0     0.00  0.00          0.00           NaN
# 12           0     0.00  0.00          0.00           NaN
# 13           0     0.00  0.00          0.00           NaN
# 14           0     0.00  0.00          0.00           NaN
# 15           0     0.00  0.00          0.00           NaN
# 16           0     0.00  0.00          0.00           NaN
# 17           0     0.00  0.00          0.00           NaN
# 18           0     0.00  0.00          0.00           NaN
# 19           0     0.00  0.00          0.00           NaN
# 20           0     0.00  0.00          0.00           NaN
# 21           0     0.00  0.00          0.00           NaN
# 22           0     0.00  0.00          0.00           NaN
# 23           0     0.00  0.00          0.00           NaN
# 24           0     0.00  0.00          0.00           NaN
# 26           0     0.00  0.00          0.00           NaN
#
#     current_inventory_qty  avg_inventory_qty  max_inventory_qty  \
# 0                    1661             553.67                630
# 1                    1743             581.00                640
# 4                     896             298.67                332
# 6                    1613             537.67                614
# 10                   1083             361.00                404
# 11                    816             272.00                324
# 12                   1690             563.33                640
# 13                    784             261.33                355
# 14                    216             216.00                216
# 15                    790             263.33                284
# 16                    990             330.00                353
# 17                    909             303.00                385
# 18                    701             233.67                310
# 19                   1880             626.67                780
# 20                   1750             583.33                641
# 21                   1052             350.67                368
# 22                    831             415.50                443
# 23                    512             170.67                209
# 24                    997             332.33                427
# 26                    798             266.00                366
#
#     min_inventory_qty  inventory_records  inventory_turnover_qty  \
# 0                 507                  3                    0.00
# 1                 518                  3                    0.00
# 4                 246                  3                    0.00
# 6                 491                  3                    0.00
# 10                324                  3                    0.00
# 11                219                  3                    0.00
# 12                516                  3                    0.00
# 13                148                  3                    0.00
# 14                216                  1                    0.00
# 15                246                  3                    0.00
# 16                316                  3                    0.00
# 17                244                  3                    0.00
# 18                187                  3                    0.00
# 19                497                  3                    0.00
# 20                540                  3                    0.00
# 21                326                  3                    0.00
# 22                388                  2                    0.00
# 23                139                  3                    0.00
# 24                196                  3                    0.00
# 26                140                  3                    0.00
#
#     days_inventory_proxy       inventory_risk_status
# 0                    NaN  No Demand - Overstock Risk
# 1                    NaN  No Demand - Overstock Risk
# 4                    NaN  No Demand - Overstock Risk
# 6                    NaN  No Demand - Overstock Risk
# 10                   NaN  No Demand - Overstock Risk
# 11                   NaN  No Demand - Overstock Risk
# 12                   NaN  No Demand - Overstock Risk
# 13                   NaN  No Demand - Overstock Risk
# 14                   NaN  No Demand - Overstock Risk
# 15                   NaN  No Demand - Overstock Risk
# 16                   NaN  No Demand - Overstock Risk
# 17                   NaN  No Demand - Overstock Risk
# 18                   NaN  No Demand - Overstock Risk
# 19                   NaN  No Demand - Overstock Risk
# 20                   NaN  No Demand - Overstock Risk
# 21                   NaN  No Demand - Overstock Risk
# 22                   NaN  No Demand - Overstock Risk
# 23                   NaN  No Demand - Overstock Risk
# 24                   NaN  No Demand - Overstock Risk
# 26                   NaN  No Demand - Overstock Risk

# %%
# Margin thấp + Inventory cao
# Nhóm cần ưu tiên
margin_cut = inventory["gross_margin"].median()

inventory_cut = inventory["current_inventory_qty"].median()

inventory_problem = inventory[

    (inventory["gross_margin"] < margin_cut)

    &

    (inventory["current_inventory_qty"] > inventory_cut)

]

inventory_problem.sort_values(

    "current_inventory_qty",

    ascending=False

).head(20)
# Out:
#      product_key                      product_name category_name  \
# 164          142     HL Mountain Frame - Black, 38    Components
# 60           125  ML Mountain Frame-W - Silver, 38    Components
# 162          166      ML Road Frame-W - Yellow, 38    Components
# 409          141    HL Mountain Frame - Silver, 38    Components
# 256          124     LL Mountain Frame - Black, 40    Components
#
#     subcategory_name  units_sold    revenue       cogs  gross_profit  \
# 164  Mountain Frames         659 501,788.20 487,028.02     14,760.18
# 60   Mountain Frames           7   1,529.18   1,395.63        133.55
# 162      Road Frames         895 303,330.84 323,043.81    -19,712.96
# 409  Mountain Frames        1206 930,780.68 901,123.44     29,657.24
# 256  Mountain Frames           8   1,198.99   1,094.28        104.71
#
#      gross_margin  current_inventory_qty  avg_inventory_qty  \
# 164          0.03                    834             139.00
# 60           0.09                    826             137.67
# 162         -0.06                    796             132.67
# 409          0.03                    738             123.00
# 256          0.09                    719             119.83
#
#      max_inventory_qty  min_inventory_qty  inventory_records  \
# 164                161                107                  6
# 60                 160                105                  6
# 162                155                100                  6
# 409                145                 91                  6
# 256                142                 88                  6
#
#      inventory_turnover_qty  days_inventory_proxy inventory_risk_status
# 164                    0.00                 30.00           Slow Moving
# 60                     0.00              3,540.00           Slow Moving
# 162                    1.00                  0.00               Healthy
# 409                    1.00                  0.00               Healthy
# 256                    0.00              2,670.00           Slow Moving

# %%
# Summary
inventory_summary = (

    inventory

    .groupby("inventory_risk_status")

    .agg(

        Products=("product_key","count"),

        Revenue=("revenue","sum"),

        Gross_Profit=("gross_profit","sum"),

        Avg_Margin=("gross_margin","mean"),

        Avg_Inventory=("current_inventory_qty","mean")

    )

)

inventory_summary
# Out:
#                             Products       Revenue  Gross_Profit  Avg_Margin  \
# inventory_risk_status
# Demand - Low Inventory            60  8,622,831.98    168,818.74        0.04
# Healthy                          163 99,523,823.21  8,904,520.01        0.17
# No Demand - Overstock Risk       222          0.00          0.00         NaN
# Slow Moving                       43  1,699,726.22    298,564.88        0.25
#
#                             Avg_Inventory
# inventory_risk_status
# Demand - Low Inventory               0.00
# Healthy                            234.88
# No Demand - Overstock Risk       1,193.95
# Slow Moving                        758.86

# %% [markdown]
# ### Nhận xét
#
# Phân tích Inventory cho thấy danh mục sản phẩm được chia thành bốn nhóm rủi ro tồn kho.
#
# - **Healthy**: Sản phẩm có tốc độ luân chuyển tốt, tồn kho phù hợp với nhu cầu bán hàng.
# - **Slow Moving**: Sản phẩm vẫn phát sinh doanh số nhưng tốc độ luân chuyển thấp, tồn kho có xu hướng tích lũy.
# - **Demand – Low Inventory**: Nhu cầu bán hàng vẫn tồn tại nhưng lượng tồn kho hiện tại thấp, cần theo dõi để tránh thiếu hàng.
# - **No Demand – Overstock Risk**: Không phát sinh doanh số nhưng vẫn còn tồn kho, đây là nhóm có rủi ro tồn kho cao nhất và cần được ưu tiên xử lý.
#
# Đặc biệt, nhóm sản phẩm có **Gross Margin thấp kết hợp với tồn kho cao** là đối tượng cần xem xét điều chỉnh chiến lược giá, chương trình khuyến mãi hoặc kế hoạch nhập hàng nhằm giảm chi phí lưu kho và cải thiện hiệu quả sử dụng vốn.

# %% [markdown]
# 5.6 Product Clustering
# - Mục tiêu
#
#     + Phân nhóm sản phẩm theo nhiều tiêu chí đồng thời thay vì chỉ dựa vào doanh thu.

# %%
# Chuẩn bị 
cluster_df = (
    product_profitability
    .merge(
        growth_summary,
        on="product_key",
        how="left"
    )
    .merge(
        inventory[
            [
                "product_key",
                "inventory_turnover_qty",
                "days_inventory_proxy",
                "inventory_risk_status"
            ]
        ],
        on="product_key",
        how="left"
    )
)

cluster_df.head()
# Out:
#    product_key            product_name category_name subcategory_name  \
# 0            1  Mountain-500 Black, 52         Bikes   Mountain Bikes
# 1            2  Mountain-500 Black, 48         Bikes   Mountain Bikes
# 2            3  Mountain-500 Black, 44         Bikes   Mountain Bikes
# 3            4  Mountain-500 Black, 42         Bikes   Mountain Bikes
# 4            5  Mountain-500 Black, 40         Bikes   Mountain Bikes
#
#      Revenue       COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 0  96,982.20  80,125.68     16,856.53         272     394.57          0.00
# 1 157,569.08 132,266.29     25,302.80         449     393.55          0.00
# 2 125,925.67 103,102.90     22,822.77         350     401.68          0.00
# 3 136,293.48 114,296.92     21,996.55         388     401.83          0.00
# 4 101,734.12  83,071.48     18,662.64         282     400.11          0.00
#
#    Gross_Margin  Avg_Growth  inventory_turnover_qty  days_inventory_proxy  \
# 0          0.17        0.14                    1.00                  0.00
# 1          0.16        0.01                    2.00                  0.00
# 2          0.18        0.11                    2.00                  0.00
# 3          0.16        0.05                    2.00                  0.00
# 4          0.18       -0.04                    1.00                  0.00
#
#   inventory_risk_status
# 0               Healthy
# 1               Healthy
# 2               Healthy
# 3               Healthy
# 4               Healthy

# %%
# Chọn feature
features = [
    "Revenue",
    "Gross_Margin",
    "Avg_Growth",
    "Avg_Discount",
    "inventory_turnover_qty"
]

cluster = cluster_df[features].copy()

# %%
# Xử lý missing
cluster = cluster.fillna(0)

# %%
# Chuẩn hóa dữ liệu
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = scaler.fit_transform(cluster)

# %%
# Elbow Method
from sklearn.cluster import KMeans

inertia = []

for k in range(2,11):

    km = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=20
    )

    km.fit(X)

    inertia.append(km.inertia_)

# %%
plt.figure(figsize=(8,5))

plt.plot(
    range(2,11),
    inertia,
    marker="o"
)

plt.xlabel("Number of Clusters")

plt.ylabel("Inertia")

plt.title("Elbow Method")

plt.show()

# %%
# Train KMeans
kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=20
)

cluster_df["Cluster"] = kmeans.fit_predict(X)

# %%
# Kiểm tra
cluster_df.head()
# Out:
#    product_key            product_name category_name subcategory_name  \
# 0            1  Mountain-500 Black, 52         Bikes   Mountain Bikes
# 1            2  Mountain-500 Black, 48         Bikes   Mountain Bikes
# 2            3  Mountain-500 Black, 44         Bikes   Mountain Bikes
# 3            4  Mountain-500 Black, 42         Bikes   Mountain Bikes
# 4            5  Mountain-500 Black, 40         Bikes   Mountain Bikes
#
#      Revenue       COGS  Gross_Profit  Units_Sold  Avg_Price  Avg_Discount  \
# 0  96,982.20  80,125.68     16,856.53         272     394.57          0.00
# 1 157,569.08 132,266.29     25,302.80         449     393.55          0.00
# 2 125,925.67 103,102.90     22,822.77         350     401.68          0.00
# 3 136,293.48 114,296.92     21,996.55         388     401.83          0.00
# 4 101,734.12  83,071.48     18,662.64         282     400.11          0.00
#
#    Gross_Margin  Avg_Growth  inventory_turnover_qty  days_inventory_proxy  \
# 0          0.17        0.14                    1.00                  0.00
# 1          0.16        0.01                    2.00                  0.00
# 2          0.18        0.11                    2.00                  0.00
# 3          0.16        0.05                    2.00                  0.00
# 4          0.18       -0.04                    1.00                  0.00
#
#   inventory_risk_status  Cluster
# 0               Healthy        0
# 1               Healthy        0
# 2               Healthy        0
# 3               Healthy        0
# 4               Healthy        0

# %%
# Thống kê từng Cluster
cluster_summary = (

    cluster_df

    .groupby("Cluster")

    .agg(

        Products=("product_key","count"),

        Revenue=("Revenue","mean"),

        Margin=("Gross_Margin","mean"),

        Growth=("Avg_Growth","mean"),

        Discount=("Avg_Discount","mean"),

        Inventory=("inventory_turnover_qty","mean")

    )

)

cluster_summary
# Out:
#          Products      Revenue  Margin  Growth  Discount  Inventory
# Cluster
# 0             187   152,003.38    0.21    0.33      0.00       4.38
# 1              28   664,528.65   -0.01    0.27      0.03       3.75
# 2              41 1,518,429.15    0.06    0.10      0.00      15.93
# 3              10    55,935.15    0.06    4.33      0.00       0.00

# %%
# PCA
from sklearn.decomposition import PCA

pca = PCA(
    n_components=2,
    random_state=42
)

X_pca = pca.fit_transform(X)

# %%
# Scatter Cluster
plt.figure(figsize=(10,8))

plt.scatter(

    X_pca[:,0],

    X_pca[:,1],

    c=cluster_df["Cluster"],

    cmap="Set2",

    alpha=0.8

)

plt.xlabel("PC1")

plt.ylabel("PC2")

plt.title("Product Clustering using K-Means")

plt.show()

# %%
# Đặt tên Cluster
cluster_name = {

    0:"High Value",

    1:"Growth Opportunity",

    2:"Discount Sensitive",

    3:"Slow Moving"

}

cluster_df["Strategy"] = (
    cluster_df["Cluster"]
    .map(cluster_name)
)

# %%
# Xem kết quả
cluster_df[
[
    "product_name",
    "Revenue",
    "Gross_Margin",
    "Avg_Growth",
    "Avg_Discount",
    "Strategy"
]
].head(20)
# Out:
#                  product_name      Revenue  Gross_Margin  Avg_Growth  \
# 0      Mountain-500 Black, 52    96,982.20          0.17        0.14
# 1      Mountain-500 Black, 48   157,569.08          0.16        0.01
# 2      Mountain-500 Black, 44   125,925.67          0.18        0.11
# 3      Mountain-500 Black, 42   136,293.48          0.16        0.05
# 4      Mountain-500 Black, 40   101,734.12          0.18       -0.04
# 5     Mountain-500 Silver, 52   161,293.35          0.02       -0.04
# 6     Mountain-500 Silver, 48   142,897.27          0.01        0.09
# 7     Mountain-500 Silver, 44   122,512.43          0.04        0.09
# 8     Mountain-500 Silver, 42   141,360.50          0.01       -0.02
# 9     Mountain-500 Silver, 40   145,089.43          0.04        0.06
# 10  Mountain-400-W Silver, 46   227,347.67          0.26        0.10
# 11  Mountain-400-W Silver, 42   217,457.87          0.26        0.10
# 12  Mountain-400-W Silver, 40   323,703.82          0.20        0.07
# 13  Mountain-400-W Silver, 38   241,773.76          0.26        0.05
# 14     Mountain-300 Black, 48   479,071.90          0.08       -0.00
# 15     Mountain-300 Black, 44   484,051.52          0.08        0.03
# 16     Mountain-300 Black, 40   501,648.88          0.07        0.04
# 17     Mountain-300 Black, 38   442,477.09          0.07        0.00
# 18     Mountain-200 Black, 46 3,309,673.22          0.20        0.04
# 19     Mountain-200 Black, 42 4,009,494.76          0.17        0.07
#
#     Avg_Discount            Strategy
# 0           0.00          High Value
# 1           0.00          High Value
# 2           0.00          High Value
# 3           0.00          High Value
# 4           0.00          High Value
# 5           0.05  Growth Opportunity
# 6           0.05  Growth Opportunity
# 7           0.05  Growth Opportunity
# 8           0.05  Growth Opportunity
# 9           0.04  Growth Opportunity
# 10          0.00          High Value
# 11          0.00          High Value
# 12          0.00          High Value
# 13          0.00          High Value
# 14          0.00          High Value
# 15          0.00          High Value
# 16          0.00          High Value
# 17          0.00          High Value
# 18          0.00  Discount Sensitive
# 19          0.00  Discount Sensitive

# %%
# Strategy Summary
strategy_summary = (

    cluster_df

    .groupby("Strategy")

    .agg(

        Products=("product_key","count"),

        Revenue=("Revenue","mean"),

        Margin=("Gross_Margin","mean"),

        Growth=("Avg_Growth","mean")

    )

)

strategy_summary
# Out:
#                     Products      Revenue  Margin  Growth
# Strategy
# Discount Sensitive        41 1,518,429.15    0.06    0.10
# Growth Opportunity        28   664,528.65   -0.01    0.27
# High Value               187   152,003.38    0.21    0.33
# Slow Moving               10    55,935.15    0.06    4.33

# %% [markdown]
# ### Nhận xét
#
# K-Means Clustering cho phép phân nhóm sản phẩm dựa trên nhiều đặc điểm cùng lúc thay vì chỉ dựa trên doanh thu hoặc lợi nhuận.
#
# Kết quả phân cụm giúp nhận diện các nhóm sản phẩm có đặc điểm tương đồng về doanh thu, biên lợi nhuận, tăng trưởng, mức giảm giá và khả năng luân chuyển tồn kho. Trên cơ sở đó, doanh nghiệp có thể áp dụng các chiến lược quản trị khác nhau cho từng nhóm, chẳng hạn như tiếp tục đầu tư vào nhóm giá trị cao, mở rộng nhóm có tiềm năng tăng trưởng, tối ưu chính sách giá đối với nhóm nhạy cảm với khuyến mãi và xử lý tồn kho đối với nhóm bán chậm.

# %% [markdown]
# 5.7 Market Basket
# - Mục tiêu
#
# - Tìm các sản phẩm thường được mua cùng nhau để:
#
#     + Bundle
#     + Cross-sell
#     + Recommendation

# %%
# Lấy dữ liệu từ Fact: dùng fact vì cần từng Oders
basket_query = """
SELECT

    sales_order_number,

    product_name

FROM dwh.fact_internet_sales f

JOIN dwh.dim_product p

ON f.product_key = p.product_key

ORDER BY sales_order_number;
"""

basket = pd.read_sql(
    basket_query,
    engine
)

basket.head()
# Out:
#   sales_order_number             product_name
# 0            SO43659   Mountain-100 Black, 44
# 1            SO43659   Mountain-100 Black, 48
# 2            SO43659  Mountain-100 Silver, 38
# 3            SO43659   Mountain-100 Black, 42
# 4            SO43659  Mountain-100 Silver, 42

# %%
# Basket Encoding
basket_matrix = (
    basket
    .assign(Value=1)
    .pivot_table(

        index="sales_order_number",

        columns="product_name",

        values="Value",

        fill_value=0

    )
)

basket_matrix.head()
# Out:
# product_name        AWC Logo Cap  All-Purpose Bike Stand  \
# sales_order_number
# SO43659                     1.00                    0.00
# SO43660                     0.00                    0.00
# SO43661                     1.00                    0.00
# SO43662                     0.00                    0.00
# SO43663                     0.00                    0.00
#
# product_name        Bike Wash - Dissolver  Cable Lock  Chain  Classic Vest, L  \
# sales_order_number
# SO43659                              0.00        0.00   0.00             0.00
# SO43660                              0.00        0.00   0.00             0.00
# SO43661                              0.00        0.00   0.00             0.00
# SO43662                              0.00        0.00   0.00             0.00
# SO43663                              0.00        0.00   0.00             0.00
#
# product_name        Classic Vest, M  Classic Vest, S  Fender Set - Mountain  \
# sales_order_number
frequent = apriori(

    basket_matrix,

    min_support=0.01, # 0.005

    use_colnames=True

)

frequent.head()
# Out:
#    support                 itemsets
# 0     0.11           (AWC Logo Cap)
# 1     0.04  (Bike Wash - Dissolver)
# 2     0.02        (Classic Vest, M)
# 3     0.02        (Classic Vest, S)
# 4     0.07  (Fender Set - Mountain)

# %%
# Association Rules
from mlxtend.frequent_patterns import association_rules

rules = association_rules(

    frequent,

    metric="lift",

    min_threshold=1

)

rules.head()
# Out:
#                antecedents              consequents  antecedent support  \
# 0  (Bike Wash - Dissolver)           (AWC Logo Cap)                0.04
# 1           (AWC Logo Cap)  (Bike Wash - Dissolver)                0.11
# 2           (AWC Logo Cap)        (Classic Vest, M)                0.11
# 3        (Classic Vest, M)           (AWC Logo Cap)                0.02
# 4        (Classic Vest, S)           (AWC Logo Cap)                0.02
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                0.11     0.01        0.29  2.68      0.01        1.25
# 1                0.04     0.01        0.11  2.68      0.01        1.08
# 2                0.02     0.01        0.10  5.50      0.01        1.09
# 3                0.11     0.01        0.59  5.50      0.01        2.18
# 4                0.11     0.01        0.61  5.66      0.01        2.28
#
#    zhangs_metric
# 0           0.65
# 1           0.70
# 2           0.92
# 3           0.83
# 4           0.84

# %%
# Lọc: lift > 1
rules = rules[

    (rules["lift"]>1)

    &

    (rules["confidence"]>0.3)

]

rules.head()
# Out:
#                 antecedents     consequents  antecedent support  \
# 3         (Classic Vest, M)  (AWC Logo Cap)                0.02
# 4         (Classic Vest, S)  (AWC Logo Cap)                0.02
# 6   (Half-Finger Gloves, M)  (AWC Logo Cap)                0.03
# 8   (Half-Finger Gloves, S)  (AWC Logo Cap)                0.03
# 11    (Hitch Rack - 4-Bike)  (AWC Logo Cap)                0.03
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 3                 0.11     0.01        0.59  5.50      0.01        2.18
# 4                 0.11     0.01        0.61  5.66      0.01        2.28
# 6                 0.11     0.02        0.50  4.66      0.01        1.79
# 8                 0.11     0.01        0.40  3.70      0.01        1.48
# 11                0.11     0.01        0.53  4.94      0.01        1.90
#
#     zhangs_metric
# 3            0.83
# 4            0.84
# 6            0.81
# 8            0.75
# 11           0.82

# %%
# Sắp xếp
rules.sort_values(

    "lift",

    ascending=False

).head(20)
# Out:
#                                              antecedents  \
# 27209  (Short-Sleeve Classic Jersey, L, Long-Sleeve L...
# 27216     (Sport-100 Helmet, Red, Bike Wash - Dissolver)
# 27516     (Sport-100 Helmet, Red, Bike Wash - Dissolver)
# 27509  (Short-Sleeve Classic Jersey, L, Short-Sleeve ...
# 35311  (Short-Sleeve Classic Jersey, L, Sport-100 Hel...
# 27508  (Short-Sleeve Classic Jersey, L, Sport-100 Hel...
# 27517  (Short-Sleeve Classic Jersey, XL, Hydration Pa...
# 35314  (Short-Sleeve Classic Jersey, XL, Hydration Pa...
# 7390      (Sport-100 Helmet, Red, Bike Wash - Dissolver)
# 7395   (Short-Sleeve Classic Jersey, XL, Hydration Pa...
# 35310                0.01     0.01        0.99 93.61      0.01      156.82
# 27218                0.01     0.01        0.94 93.61      0.01       17.40
# 27207                0.01     0.01        0.99 93.61      0.01      156.82
# 35315                0.01     0.01        0.94 93.61      0.01       17.40
# 28890                0.01     0.01        0.98 93.57      0.01       52.94
# 28895                0.01     0.01        0.95 93.57      0.01       21.78
#
#        zhangs_metric
# 27209           1.00
# 27216           1.00
# 27516           1.00
# 27509           1.00
# 35311           1.00
# 27508           1.00
# 27517           1.00
# 35314           1.00
# 7390            1.00
# 7395            1.00
# 35312           1.00
# 35313           1.00
# 27217           1.00
# 27208           1.00
# 35310           1.00
# 27218           1.00
# 27207           1.00
# 35315           1.00
# 28890           1.00
# 28895           1.00

# %%
# Format
market_basket = rules[
[
    "antecedents",
    "consequents",
    "support",
    "confidence",
    "lift"
]
]

market_basket
# Out:
#                                     antecedents  \
# 3                             (Classic Vest, M)
# 4                             (Classic Vest, S)
# 6                       (Half-Finger Gloves, M)
# 8                       (Half-Finger Gloves, S)
# 11                        (Hitch Rack - 4-Bike)
# ...                                         ...
# 169035  (AWC Logo Cap, Sport-100 Helmet, Black)
# 169038                    (Hitch Rack - 4-Bike)
# 169039                        (Classic Vest, S)
# 169041        (Short-Sleeve Classic Jersey, XL)
# 169042         (Short-Sleeve Classic Jersey, L)
#
#                                               consequents  support  \
# 3                                          (AWC Logo Cap)     0.01
# 4                                          (AWC Logo Cap)     0.01
# 6                                          (AWC Logo Cap)     0.02
# 8                                          (AWC Logo Cap)     0.01
# 11                                         (AWC Logo Cap)     0.01
# ...                                                   ...      ...
# 169035  (Water Bottle - 30 oz., Bike Wash - Dissolver,...     0.01
# 169038  (Water Bottle - 30 oz., Bike Wash - Dissolver,...     0.01
# 169039  (Water Bottle - 30 oz., Bike Wash - Dissolver,...     0.01
# 169041  (Water Bottle - 30 oz., Bike Wash - Dissolver,...     0.01
# 169042  (Water Bottle - 30 oz., Bike Wash - Dissolver,...     0.01
#
#         confidence  lift
# 3             0.59  5.50
# 4             0.61  5.66
# 6             0.50  4.66
# 8             0.40  3.70
# 11            0.53  4.94
# ...            ...   ...
# 169035        0.33 31.36
# 169038        0.41 39.17
# 169039        0.47 45.85
# 169041        0.36 34.81
# 169042        0.40 39.09
#
# [159335 rows x 5 columns]

# %%
# Chuyển Set thành String
market_basket["antecedents"] = (

    market_basket["antecedents"]

    .apply(

        lambda x:", ".join(list(x))

    )

)

market_basket["consequents"] = (

    market_basket["consequents"]

    .apply(

        lambda x:", ".join(list(x))

    )

)

market_basket.head(20)
# Out:
# /tmp/ipykernel_376/3916293722.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   market_basket["antecedents"] = (
# /tmp/ipykernel_376/3916293722.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   market_basket["consequents"] = (
#                         antecedents                 consequents  support  \
# 3                   Classic Vest, M                AWC Logo Cap     0.01
# 4                   Classic Vest, S                AWC Logo Cap     0.01
# 6             Half-Finger Gloves, M                AWC Logo Cap     0.02
# 8             Half-Finger Gloves, S                AWC Logo Cap     0.01
# 11              Hitch Rack - 4-Bike                AWC Logo Cap     0.01
# 13          Hydration Pack - 70 oz.                AWC Logo Cap     0.01
# 14        LL Road Frame - Black, 52                AWC Logo Cap     0.01
# 16                     AWC Logo Cap  Long-Sleeve Logo Jersey, L     0.04
# 17       Long-Sleeve Logo Jersey, L                AWC Logo Cap     0.04
# 18       Long-Sleeve Logo Jersey, M                AWC Logo Cap     0.02
# 20      Long-Sleeve Logo Jersey, XL                AWC Logo Cap     0.02
# 22              Men's Bib-Shorts, M                AWC Logo Cap     0.01
# 24               Road-650 Black, 52                AWC Logo Cap     0.01
# 27               Road-650 Black, 58                AWC Logo Cap     0.01
# 29                 Road-650 Red, 44                AWC Logo Cap     0.01
# 30                 Road-650 Red, 48                AWC Logo Cap     0.01
# 33                 Road-650 Red, 60                AWC Logo Cap     0.01
# 34   Short-Sleeve Classic Jersey, L                AWC Logo Cap     0.02
# 37   Short-Sleeve Classic Jersey, S                AWC Logo Cap     0.01
# 39  Short-Sleeve Classic Jersey, XL                AWC Logo Cap     0.02
#
#     confidence  lift
# 3         0.59  5.50
# 4         0.61  5.66
# 6         0.50  4.66
# 8         0.40  3.70
# 11        0.53  4.94
# 13        0.33  3.09
# 14        0.58  5.35
# 16        0.35  6.67
# 17        0.72  6.67
# 18        0.61  5.66
# 20        0.60  5.57
# 22        0.90  8.35
# 24        0.49  4.58
# 27        0.50  4.67
# 29        0.50  4.63
# 30        0.49  4.54
# 33        0.51  4.75
# 34        0.60  5.54
# 37        0.49  4.54
# 39        0.56  5.18

# %%
# Top Bundle
market_basket.sort_values(

    "lift",

    ascending=False

).head(10)
# Out:
#                                              antecedents  \
# 27209  Short-Sleeve Classic Jersey, L, Long-Sleeve Lo...
# 27216       Sport-100 Helmet, Red, Bike Wash - Dissolver
# 27516       Sport-100 Helmet, Red, Bike Wash - Dissolver
# 27509  Short-Sleeve Classic Jersey, L, Short-Sleeve C...
# 35311  Short-Sleeve Classic Jersey, L, Sport-100 Helm...
# 27508  Short-Sleeve Classic Jersey, L, Sport-100 Helm...
# 27517  Short-Sleeve Classic Jersey, XL, Hydration Pac...
# 35314  Short-Sleeve Classic Jersey, XL, Hydration Pac...
# 7390        Sport-100 Helmet, Red, Bike Wash - Dissolver
# 7395   Short-Sleeve Classic Jersey, XL, Hydration Pac...
#
#                                              consequents  support  confidence  \
# 27209       Sport-100 Helmet, Red, Bike Wash - Dissolver     0.01        0.98
# 27216  Short-Sleeve Classic Jersey, L, Long-Sleeve Lo...     0.01        0.98
# 27516  Short-Sleeve Classic Jersey, L, Short-Sleeve C...     0.01        0.98
# 27509       Sport-100 Helmet, Red, Bike Wash - Dissolver     0.01        0.98
# 35311  Short-Sleeve Classic Jersey, XL, Hydration Pac...     0.01        0.99
# 27508  Short-Sleeve Classic Jersey, XL, Hydration Pac...     0.01        0.99
# 27517  Short-Sleeve Classic Jersey, L, Sport-100 Helm...     0.01        0.96
# 35314  Short-Sleeve Classic Jersey, L, Sport-100 Helm...     0.01        0.96
# 7390   Short-Sleeve Classic Jersey, XL, Hydration Pac...     0.01        0.98
# 7395        Sport-100 Helmet, Red, Bike Wash - Dissolver     0.01        0.96
#
#        lift
# 27209 95.89
# 27216 95.89
# 27516 95.89
# 27509 95.89
# 35311 94.74
# 27508 94.74
# 27517 94.74
# 35314 94.74
# 7390  94.14
# 7395  94.14

# %% [markdown]
# ### Nhận xét
#
# Market Basket Analysis giúp phát hiện các sản phẩm thường được mua cùng trong cùng một đơn hàng.
#
# Các luật kết hợp có Lift lớn hơn 1 cho thấy xác suất hai sản phẩm được mua cùng cao hơn so với ngẫu nhiên. Đây là cơ sở để xây dựng các chương trình bundle, cross-sell hoặc recommendation trên website.
#
# Các cặp sản phẩm có Support và Confidence cao nên được ưu tiên trong các chương trình bán kèm nhằm gia tăng giá trị đơn hàng và cải thiện doanh thu.

# %% [markdown]
# 5.8 Forecast
# - Mục tiêu
#
# - Dự báo nhu cầu và doanh thu trong tương lai, đồng thời so sánh mô hình đơn giản (Seasonal Naive) với mô hình Machine Learning (XGBoost).

# %%
# Chuẩn bị dữ liệu
forecast = (
    profit_df
    .groupby(
        ["month_key", "category_name"],
        as_index=False
    )
    .agg(
        Revenue=("revenue", "sum"),
        Quantity=("quantity", "sum"),
        Avg_Price=("avg_unit_price", "mean"),
        Avg_Discount=("avg_discount_rate", "mean")
    )
)

forecast.head()
# Out:
#   month_key category_name    Revenue  Quantity  Avg_Price  Avg_Discount
# 0    202205   Accessories   1,695.67        84      20.19          0.00
# 1    202205         Bikes 481,640.66       464   1,270.75          0.00
# 2    202205      Clothing   2,875.15       167      18.04          0.00
# 3    202205    Components  31,525.96       114     355.32          0.00
# 4    202206   Accessories   3,593.20       178      20.19          0.00

# %%
# Chọn một Category
category = "Bikes"

bike = forecast[
    forecast["category_name"] == category
].copy()

# %%
# Chuyển Month
bike["month"] = pd.to_datetime(
    bike["month_key"],
    format="%Y%m"
)

bike = bike.sort_values("month")

# %%
# Feature Engineering
# lag
bike["lag1"] = bike["Revenue"].shift(1)
bike["lag2"] = bike["Revenue"].shift(2)
bike["lag3"] = bike["Revenue"].shift(3)

# rolling mean
bike["rolling3"] = (
    bike["Revenue"]
    .rolling(3)
    .mean()
)

# rolling Std
bike["rolling_std3"] = (
    bike["Revenue"]
    .rolling(3)
    .std()
)

# month
bike["month_num"] = bike["month"].dt.month

# quarter
bike["quarter"] = bike["month"].dt.quarter

# promotion
bike["promotion"] = (
    bike["Avg_Discount"] > 0
).astype(int)

# %%
# Drop NA
bike = bike.dropna()

# %%
# train/Test
train = bike.iloc[:-6]

test = bike.iloc[-6:]

# %%
# Seasonal Naive
test["Naive"] = (
    test["lag1"]
)
# Out:
# /tmp/ipykernel_376/135440659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["Naive"] = (

# %%
# XGBoost
from xgboost import XGBRegressor

features = [
    "lag1",
    "lag2",
    "lag3",
    "rolling3",
    "rolling_std3",
    "Avg_Price",
    "Avg_Discount",
    "promotion",
    "month_num",
    "quarter"
]

# train
model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

model.fit(
    train[features],
    train["Revenue"]
)

# predict
test["XGBoost"] = model.predict(
    test[features]
)
# Out:
# /tmp/ipykernel_376/3172365493.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["XGBoost"] = model.predict(

# %%
# Đánh giá
from sklearn.metrics import mean_absolute_error

print(
    "Naive MAE:",
    mean_absolute_error(
        test["Revenue"],
        test["Naive"]
    )
)

print(
    "XGBoost MAE:",
    mean_absolute_error(
        test["Revenue"],
        test["XGBoost"]
    )
)

# Nếu XGBoost có MAE thấp hơn thì mô hình học được quy luật tốt hơn.
# Out:
# Naive MAE: 947309.7689006664
# XGBoost MAE: 599534.6043181666

# %%
# Biểu đồ
plt.figure(figsize=(12,6))

plt.plot(
    bike["month"],
    bike["Revenue"],
    label="Actual"
)

plt.plot(
    test["month"],
    test["Naive"],
    label="Seasonal Naive"
)

plt.plot(
    test["month"],
    test["XGBoost"],
    label="XGBoost"
)

plt.legend()

plt.title("Revenue Forecast - Bikes")

plt.show()

# %%
# Feature Importance
importance = pd.DataFrame({
    "Feature": features,
    "Importance": model.feature_importances_
})

importance.sort_values(
    "Importance",
    ascending=False
)
# Out:
#         Feature  Importance
# 5     Avg_Price        0.51
# 3      rolling3        0.26
# 0          lag1        0.09
# 2          lag3        0.06
# 1          lag2        0.03
# 8     month_num        0.02
# 4  rolling_std3        0.02
# 6  Avg_Discount        0.01
# 7     promotion        0.00
# 9       quarter        0.00

# %% [markdown]
# ### Nhận xét
#
# Mô hình dự báo được xây dựng nhằm ước lượng doanh thu của nhóm sản phẩm trong các tháng tiếp theo. Bộ đặc trưng sử dụng bao gồm doanh thu các tháng trước (lag), giá trị trung bình trượt (rolling mean), độ biến động (rolling standard deviation), giá bán trung bình, tỷ lệ giảm giá và các đặc trưng mùa vụ như tháng và quý.
#
# Kết quả so sánh cho thấy mô hình XGBoost có sai số dự báo thấp hơn mô hình Seasonal Naive, cho thấy việc kết hợp các đặc trưng lịch sử và yếu tố kinh doanh giúp cải thiện khả năng dự báo doanh thu. Mô hình này có thể hỗ trợ doanh nghiệp trong việc lập kế hoạch bán hàng, quản lý tồn kho và chuẩn bị nguồn lực cho các kỳ kinh doanh tiếp theo.

# %% [markdown]
# ## 6. Business Insights

# %% [markdown]
# Insight 1: Bikes tạo doanh thu lớn nhưng không phải là nhóm có Gross Margin cao nhất.

# %%
# Chuẩn bị bảng phân tích
category_analysis = (
    profit_df
    .groupby("category_name", as_index=False)
    .agg(
        Revenue=("revenue", "sum"),
        Gross_Profit=("gross_profit", "sum"),
        Gross_Margin=("gross_margin", "mean"),
        Quantity=("quantity", "sum")
    )
)

category_analysis = category_analysis.sort_values(
    "Revenue",
    ascending=False
)

category_analysis
# Out:
#   category_name       Revenue  Gross_Profit  Gross_Margin  Quantity
# 1         Bikes 94,651,172.70  7,936,394.02          0.08     90268
# 3    Components 11,802,593.29    490,233.18          0.11     49044
# 2      Clothing  2,120,542.52    308,882.17          0.20     73670
# 0   Accessories  1,272,072.88    636,394.26          0.51     61932

# %%
# Kiểm tra xem Bikes có thật sự Margin cao không
category_analysis.sort_values(
    "Gross_Margin",
    ascending=False
)
# Out:
#   category_name       Revenue  Gross_Profit  Gross_Margin  Quantity
# 0   Accessories  1,272,072.88    636,394.26          0.51     61932
# 2      Clothing  2,120,542.52    308,882.17          0.20     73670
# 3    Components 11,802,593.29    490,233.18          0.11     49044
# 1         Bikes 94,651,172.70  7,936,394.02          0.08     90268

# %%
# Vẽ biểu đồ Revenue
plt.figure(figsize=(10,6))

plt.bar(
    category_analysis["category_name"],
    category_analysis["Revenue"]
)

plt.title("Bikes đóng góp phần lớn doanh thu của AdventureWorks")

plt.ylabel("Revenue")

plt.xlabel("Category")

plt.show()

# %%
# Vẽ Gross Margin
plt.figure(figsize=(10,6))

plt.bar(
    category_analysis["category_name"],
    category_analysis["Gross_Margin"]
)

plt.title("So sánh Gross Margin theo danh mục sản phẩm")

plt.ylabel("Gross Margin")

plt.xlabel("Category")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.bar(
    category_analysis["category_name"],
    category_analysis["Gross_Profit"]
)

plt.title("Gross Profit theo danh mục sản phẩm")

plt.xlabel("Category")
plt.ylabel("Gross Profit")

plt.show()

# %% [markdown]
# Insight 2: Một số sản phẩm thuộc nhóm A theo doanh thu nhưng chỉ thuộc nhóm B theo lợi nhuận.

# %%
# Tìm sản phẩm A Revenue nhưng B/C Profit
abc_detail = (
    abc_revenue[
        [
            "product_key",
            "product_name",
            "Revenue",
            "ABC_Revenue"
        ]
    ]
    .merge(
        abc_profit[
            [
                "product_key",
                "Gross_Profit",
                "ABC_Profit"
            ]
        ],
        on="product_key"
    )
)

abc_detail.head()
# Out:
#    product_key             product_name      Revenue ABC_Revenue  \
# 0           21   Mountain-200 Black, 38 4,400,592.80           A
# 1           20   Mountain-200 Black, 42 4,009,494.76           A
# 2           24  Mountain-200 Silver, 38 3,693,678.03           A
# 3           23  Mountain-200 Silver, 42 3,438,478.86           A
# 4           22  Mountain-200 Silver, 46 3,434,256.94           A
#
#    Gross_Profit ABC_Profit
# 0    673,444.47          A
# 1    674,216.58          A
# 2    663,784.94          A
# 3    611,084.90          A
# 4    629,644.13          A

# %%
# Lọc các sản phẩm đáng chú ý
abc_gap = abc_detail[
    (abc_detail["ABC_Revenue"] == "A") &
    (abc_detail["ABC_Profit"] != "A")
]

abc_gap.sort_values(
    "Revenue",
    ascending=False
)
# Out:
#     product_key                    product_name      Revenue ABC_Revenue  \
# 6            49              Road-250 Black, 44 2,516,857.31           A
# 7            48              Road-250 Black, 48 2,347,655.95           A
# 8            47              Road-250 Black, 52 2,012,447.77           A
# 10           37           Road-350-W Yellow, 48 1,774,883.56           A
# 12           81           Touring-1000 Blue, 60 1,721,242.51           A
# 13           40           Road-350-W Yellow, 40 1,657,198.18           A
# 17           93         Touring-1000 Yellow, 60 1,518,133.10           A
# 20           96         Touring-1000 Yellow, 46 1,426,372.87           A
# 25           28          Mountain-100 Black, 38 1,339,997.25           A
# 26           32         Mountain-100 Silver, 38 1,291,868.70           A
# 27           27          Mountain-100 Black, 42 1,254,722.73           A
# 28           25          Mountain-100 Black, 48 1,234,276.03           A
# 29           41           Road-550-W Yellow, 48 1,233,938.88           A
# 30           45           Road-550-W Yellow, 38 1,227,910.08           A
# 31           30         Mountain-100 Silver, 44 1,217,210.36           A
# 32           31         Mountain-100 Silver, 42 1,186,494.85           A
# 35           44           Road-550-W Yellow, 40 1,071,291.78           A
# 37           54              Road-650 Black, 52 1,042,909.78           A
# 38           29         Mountain-100 Silver, 48 1,019,657.00           A
# 39           64                Road-650 Red, 60 1,016,529.02           A
# 40           95         Touring-1000 Yellow, 50   981,187.85           A
# 41           62                Road-650 Red, 44   943,340.56           A
# 42           43           Road-550-W Yellow, 42   932,039.59           A
# 43          141  HL Mountain Frame - Silver, 38   930,780.68           A
# 44          146   HL Mountain Frame - Black, 42   901,590.23           A
# 45           63                Road-650 Red, 62   879,827.94           A
# 46           61                Road-650 Red, 48   878,666.66           A
# 47           59              Road-650 Black, 58   869,632.78           A
# 48           78           Touring-2000 Blue, 54   772,302.01           A
# 50           42           Road-550-W Yellow, 44   717,825.91           A
# 53           97           Touring-2000 Blue, 60   635,723.72           A
# 54           66                Road-450 Red, 52   621,103.74           A
# 55           34              Road-750 Black, 48   578,174.31           A
# 56           60                Road-650 Red, 52   523,630.15           A
# 57           58              Road-650 Black, 60   521,898.26           A
# 58           33              Road-750 Black, 52   515,666.91           A
# 59           56              Road-650 Black, 44   509,245.01           A
# 60           70                Road-450 Red, 58   507,978.30           A
# 61          142   HL Mountain Frame - Black, 38   501,788.20           A
# 62           17          Mountain-300 Black, 40   501,648.88           A
#
#     Gross_Profit ABC_Profit
# 6     -36,367.14          C
# 7      18,344.00          C
# 8      76,537.64          B
# 10     19,052.34          C
# 12     61,472.07          B
# 13     58,330.91          B
# 17   -132,745.72          C
# 20    -62,974.72          C
# 25     45,496.87          B
# 26     64,265.58          B
# 27     51,330.88          B
# 28     65,049.88          B
# 29    -23,220.81          C
# 30    -15,701.09          C
# 31     68,005.57          B
# 32     52,587.29          B
# 35      1,672.08          C
# 37    -61,914.20          C
# 38     54,019.03          B
# 39    -69,800.11          C
# 40     14,964.34          C
# 41   -153,696.12          C
# 42     41,402.92          C
# 43     29,657.24          C
# 44     28,782.81          C
# 45    -42,967.78          C
# 46    -40,235.40          C
# 47    -40,995.27          C
# 48      9,599.70          C
# 50     56,800.94          B
# 53     16,500.06          C
# 54     -7,039.15          C
# 55     43,455.54          C
# 56    -17,587.59          C
# 57    -13,479.00          C
# 58     55,863.74          B
# 59    -16,398.12          C
# 60     -6,921.93          C
# 61     14,760.18          C
# 62     37,263.00          C

# %%
# Giải thích nguyên nhân
gap_analysis = (
    abc_gap
    .merge(
        product_profitability[
            [
                "product_key",
                "COGS",
                "Gross_Margin",
                "Avg_Discount"
            ]
        ],
        on="product_key",
        how="left"
    )
)
gap_analysis.head()
# Out:
#    product_key           product_name      Revenue ABC_Revenue  Gross_Profit  \
# 0           49     Road-250 Black, 44 2,516,857.31           A    -36,367.14
# 1           48     Road-250 Black, 48 2,347,655.95           A     18,344.00
# 2           47     Road-250 Black, 52 2,012,447.77           A     76,537.64
# 3           37  Road-350-W Yellow, 48 1,774,883.56           A     19,052.34
# 4           81  Touring-1000 Blue, 60 1,721,242.51           A     61,472.07
#
#   ABC_Profit         COGS  Gross_Margin  Avg_Discount
# 0          C 2,553,224.45         -0.01          0.00
# 1          C 2,329,311.95          0.01          0.00
# 2          B 1,935,910.14          0.04          0.00
# 3          C 1,755,831.22          0.01          0.00
# 4          B 1,659,770.45          0.04          0.00

# %%
# Kiểm tra Discount
gap_analysis.sort_values(
    "Avg_Discount",
    ascending=False
)
# Out:
#     product_key                    product_name      Revenue ABC_Revenue  \
# 6            93         Touring-1000 Yellow, 60 1,518,133.10           A
# 7            96         Touring-1000 Yellow, 46 1,426,372.87           A
# 20           95         Touring-1000 Yellow, 50   981,187.85           A
# 10           27          Mountain-100 Black, 42 1,254,722.73           A
# 14           30         Mountain-100 Silver, 44 1,217,210.36           A
# 11           25          Mountain-100 Black, 48 1,234,276.03           A
# 18           29         Mountain-100 Silver, 48 1,019,657.00           A
# 21           62                Road-650 Red, 44   943,340.56           A
# 8            28          Mountain-100 Black, 38 1,339,997.25           A
# 15           31         Mountain-100 Silver, 42 1,186,494.85           A
# 9            32         Mountain-100 Silver, 38 1,291,868.70           A
# 3            37           Road-350-W Yellow, 48 1,774,883.56           A
# 19           64                Road-650 Red, 60 1,016,529.02           A
# 5            40           Road-350-W Yellow, 40 1,657,198.18           A
# 4            81           Touring-1000 Blue, 60 1,721,242.51           A
# 17           54              Road-650 Black, 52 1,042,909.78           A
# 32           34              Road-750 Black, 48   578,174.31           A
# 25           63                Road-650 Red, 62   879,827.94           A
# 28           78           Touring-2000 Blue, 54   772,302.01           A
# 12           41           Road-550-W Yellow, 48 1,233,938.88           A
# 26           61                Road-650 Red, 48   878,666.66           A
# 27           59              Road-650 Black, 58   869,632.78           A
# 39           17          Mountain-300 Black, 40   501,648.88           A
# 35           33              Road-750 Black, 52   515,666.91           A
# 13           45           Road-550-W Yellow, 38 1,227,910.08           A
# 0            49              Road-250 Black, 44 2,516,857.31           A
# 30           97           Touring-2000 Blue, 60   635,723.72           A
# 37           70                Road-450 Red, 58   507,978.30           A
# 1            48              Road-250 Black, 48 2,347,655.95           A
# 34           58              Road-650 Black, 60   521,898.26           A
# 16           44           Road-550-W Yellow, 40 1,071,291.78           A
# 36           56              Road-650 Black, 44   509,245.01           A
# 23          141  HL Mountain Frame - Silver, 38   930,780.68           A
# 33           60                Road-650 Red, 52   523,630.15           A
# 2            47              Road-250 Black, 52 2,012,447.77           A
# 24          146   HL Mountain Frame - Black, 42   901,590.23           A
# 29           42           Road-550-W Yellow, 44   717,825.91           A
# 22           43           Road-550-W Yellow, 42   932,039.59           A
# 38          142   HL Mountain Frame - Black, 38   501,788.20           A
# 31           66                Road-450 Red, 52   621,103.74           A
#
#     Gross_Profit ABC_Profit         COGS  Gross_Margin  Avg_Discount
# 6    -132,745.72          C 1,650,878.82         -0.09          0.03
# 7     -62,974.72          C 1,489,347.59         -0.04          0.03
# 20     14,964.34          C   966,223.51          0.02          0.03
# 31     -7,039.15          C   628,142.89         -0.01          0.00
# 30     16,500.06          C   619,223.66          0.03          0.00
# 33    -17,587.59          C   541,217.74         -0.03          0.00
# 34    -13,479.00          C   535,377.26         -0.03          0.00
# 32     43,455.54          C   534,718.78          0.08          0.00
# 36    -16,398.12          C   525,643.13         -0.03          0.00
# 37     -6,921.93          C   514,900.23         -0.01          0.00
# 38     14,760.18          C   487,028.02          0.03          0.00
# 39     37,263.00          C   464,385.87          0.07          0.00
# 35     55,863.74          B   459,803.16          0.11          0.00

# %%
# Kiểm tra Margin
gap_analysis.sort_values(
    "Gross_Margin"
)
# Out:
#     product_key                    product_name      Revenue ABC_Revenue  \
# 21           62                Road-650 Red, 44   943,340.56           A
# 6            93         Touring-1000 Yellow, 60 1,518,133.10           A
# 19           64                Road-650 Red, 60 1,016,529.02           A
# 17           54              Road-650 Black, 52 1,042,909.78           A
# 25           63                Road-650 Red, 62   879,827.94           A
# 27           59              Road-650 Black, 58   869,632.78           A
# 26           61                Road-650 Red, 48   878,666.66           A
# 7            96         Touring-1000 Yellow, 46 1,426,372.87           A
# 33           60                Road-650 Red, 52   523,630.15           A
# 36           56              Road-650 Black, 44   509,245.01           A
# 34           58              Road-650 Black, 60   521,898.26           A
# 12           41           Road-550-W Yellow, 48 1,233,938.88           A
# 0            49              Road-250 Black, 44 2,516,857.31           A
# 37           70                Road-450 Red, 58   507,978.30           A
# 13           45           Road-550-W Yellow, 38 1,227,910.08           A
# 31           66                Road-450 Red, 52   621,103.74           A
# 16           44           Road-550-W Yellow, 40 1,071,291.78           A
# 1            48              Road-250 Black, 48 2,347,655.95           A
# 3            37           Road-350-W Yellow, 48 1,774,883.56           A
# 28           78           Touring-2000 Blue, 54   772,302.01           A
# 20           95         Touring-1000 Yellow, 50   981,187.85           A
# 30           97           Touring-2000 Blue, 60   635,723.72           A
# 38          142   HL Mountain Frame - Black, 38   501,788.20           A
# 23          141  HL Mountain Frame - Silver, 38   930,780.68           A
# 24          146   HL Mountain Frame - Black, 42   901,590.23           A
# 8            28          Mountain-100 Black, 38 1,339,997.25           A
# 5            40           Road-350-W Yellow, 40 1,657,198.18           A
# 4            81           Touring-1000 Blue, 60 1,721,242.51           A
# 2            47              Road-250 Black, 52 2,012,447.77           A
# 10           27          Mountain-100 Black, 42 1,254,722.73           A
# 15           31         Mountain-100 Silver, 42 1,186,494.85           A
# 22           43           Road-550-W Yellow, 42   932,039.59           A
# 9            32         Mountain-100 Silver, 38 1,291,868.70           A
# 11           25          Mountain-100 Black, 48 1,234,276.03           A
# 18           29         Mountain-100 Silver, 48 1,019,657.00           A
# 14           30         Mountain-100 Silver, 44 1,217,210.36           A
# 39           17          Mountain-300 Black, 40   501,648.88           A
# 32           34              Road-750 Black, 48   578,174.31           A
# 29           42           Road-550-W Yellow, 44   717,825.91           A
# 35           33              Road-750 Black, 52   515,666.91           A
#
#     Gross_Profit ABC_Profit         COGS  Gross_Margin  Avg_Discount
# 21   -153,696.12          C 1,097,036.68         -0.16          0.02
# 6    -132,745.72          C 1,650,878.82         -0.09          0.03
# 19    -69,800.11          C 1,086,329.13         -0.07          0.00
# 17    -61,914.20          C 1,104,823.98         -0.06          0.00
# 25    -42,967.78          C   922,795.71         -0.05          0.00
# 27    -40,995.27          C   910,628.05         -0.05          0.00
# 26    -40,235.40          C   918,902.06         -0.05          0.00
# 7     -62,974.72          C 1,489,347.59         -0.04          0.03
# 33    -17,587.59          C   541,217.74         -0.03          0.00
# 36    -16,398.12          C   525,643.13         -0.03          0.00
# 34    -13,479.00          C   535,377.26         -0.03          0.00
# 12    -23,220.81          C 1,257,159.69         -0.02          0.00
# 0     -36,367.14          C 2,553,224.45         -0.01          0.00
# 37     -6,921.93          C   514,900.23         -0.01          0.00
# 13    -15,701.09          C 1,243,611.17         -0.01          0.00
# 31     -7,039.15          C   628,142.89         -0.01          0.00
# 16      1,672.08          C 1,069,619.70          0.00          0.00
# 1      18,344.00          C 2,329,311.95          0.01          0.00
# 3      19,052.34          C 1,755,831.22          0.01          0.00
# 28      9,599.70          C   762,702.31          0.01          0.00
# 20     14,964.34          C   966,223.51          0.02          0.03
# 30     16,500.06          C   619,223.66          0.03          0.00
# 38     14,760.18          C   487,028.02          0.03          0.00
# 23     29,657.24          C   901,123.44          0.03          0.00
# 24     28,782.81          C   872,807.42          0.03          0.00
# 8      45,496.87          B 1,294,500.38          0.03          0.02
# 5      58,330.91          B 1,598,867.27          0.04          0.00
# 4      61,472.07          B 1,659,770.45          0.04          0.00
# 2      76,537.64          B 1,935,910.14          0.04          0.00
# 10     51,330.88          B 1,203,391.85          0.04          0.02
# 15     52,587.29          B 1,133,907.56          0.04          0.02
# 22     41,402.92          C   890,636.67          0.04          0.00
# 9      64,265.58          B 1,227,603.12          0.05          0.02
# 11     65,049.88          B 1,169,226.15          0.05          0.02
# 18     54,019.03          B   965,637.97          0.05          0.02
# 14     68,005.57          B 1,149,204.79          0.06          0.02
# 39     37,263.00          C   464,385.87          0.07          0.00
# 32     43,455.54          C   534,718.78          0.08          0.00
# 29     56,800.94          B   661,024.97          0.08          0.00
# 35     55,863.74          B   459,803.16          0.11          0.00

# %%
# Vẽ biểu đồ
# Top sản phẩm Revenue A nhưng Profit B/C
plt.figure(figsize=(12,6))

plt.bar(
    gap_analysis["product_name"],
    gap_analysis["Revenue"]
)

plt.xticks(rotation=90)

plt.title("Products with High Revenue but Lower Profit Class")

plt.ylabel("Revenue")

plt.show()

# So sánh Margin
plt.figure(figsize=(12,6))

plt.bar(
    gap_analysis["product_name"],
    gap_analysis["Gross_Margin"]
)

plt.xticks(rotation=90)

plt.title("Gross Margin of Revenue A but Profit B/C Products")

plt.ylabel("Gross Margin")

plt.show()

# %% [markdown]
# Insight 3: Nhóm Slow Moving chiếm khoảng xx% danh mục.

# %%
# Thống kê Inventory Risk
inventory_summary = (
    inventory
    .groupby("inventory_risk_status", as_index=False)
    .agg(
        Products=("product_key", "count")
    )
)

inventory_summary
# Out:
#         inventory_risk_status  Products
# 0      Demand - Low Inventory        60
# 1                     Healthy       163
# 2  No Demand - Overstock Risk       222
# 3                 Slow Moving        43

# %%
# Tính tỷ trọng
inventory_summary["Contribution (%)"] = (
    inventory_summary["Products"]
    / inventory_summary["Products"].sum()
    * 100
).round(2)

inventory_summary
# Out:
#         inventory_risk_status  Products  Contribution (%)
# 0      Demand - Low Inventory        60             12.30
# 1                     Healthy       163             33.40
# 2  No Demand - Overstock Risk       222             45.49
# 3                 Slow Moving        43              8.81

# %%
# Vẽ biểu đồ
plt.figure(figsize=(8,5))

plt.bar(
    inventory_summary["inventory_risk_status"],
    inventory_summary["Products"]
)

plt.title("Phân bố sản phẩm theo Inventory Risk")

plt.xlabel("Inventory Status")
plt.ylabel("Number of Products")

plt.xticks(rotation=15)

plt.show()

# %%
# Riêng nhóm Slow Moving
slow_moving = inventory[
    inventory["inventory_risk_status"] == "Slow Moving"
]

slow_moving.head()
# Out:
#     product_key            product_name category_name subcategory_name  \
# 2           116         Rear Derailleur    Components      Derailleurs
# 33          156       ML Mountain Pedal    Components           Pedals
# 41          227     ML Road Front Wheel    Components           Wheels
# 49          103  HL Mountain Handlebars    Components       Handlebars
# 54          121              ML Headset    Components         Headsets
#
#     units_sold   revenue      cogs  gross_profit  gross_margin  \
# 2          353 25,725.23 19,036.65      6,688.57          0.26
# 33         345 12,852.63  9,510.96      3,341.67          0.26
# 41         532 79,354.04 58,670.50     20,683.54          0.26
# 49         500 34,375.35 26,699.95      7,675.40          0.22
# 54         659 39,909.11 29,929.67      9,979.44          0.25
#
#     current_inventory_qty  avg_inventory_qty  max_inventory_qty  \
# 2                     847             282.33                355
# 33                    507             169.00                180
# 41                    793             396.50                409
# 49                    840             280.00                310
# 54                    772             257.33                288
#
#     min_inventory_qty  inventory_records  inventory_turnover_qty  \
# 2                 155                  3                    0.00
# 33                155                  3                    0.00
# 41                384                  2                    0.00
# 49                260                  3                    0.00
# 54                216                  3                    0.00
#
#     days_inventory_proxy inventory_risk_status
# 2                  60.00           Slow Moving
# 33                 30.00           Slow Moving
# 41                 30.00           Slow Moving
# 49                 30.00           Slow Moving
# 54                 30.00           Slow Moving

# %%
# Top tồn kho lớn nhất
slow_moving.sort_values(
    "current_inventory_qty",
    ascending=False
)[
    [
        "product_name",
        "category_name",
        "current_inventory_qty",
        "units_sold",
        "gross_margin"
    ]
].head(20)
# Out:
#                          product_name category_name  current_inventory_qty  \
# 402            HL Touring Seat/Saddle    Components                    989
# 192                 HL Bottom Bracket    Components                    970
# 250                       HL Crankset    Components                    923
# 166                     HL Road Pedal    Components                    906
# 67                LL Road Seat/Saddle    Components                    906
# 61                        ML Crankset    Components                    905
# 55                            HL Fork    Components                    901
# 308                     Touring Pedal    Components                    885
# 242                       LL Crankset    Components                    885
# 266                           LL Fork    Components                    863
# 241                  Front Derailleur    Components                    853
# 2                     Rear Derailleur    Components                    847
# 49             HL Mountain Handlebars    Components                    840
# 121                ML Road Rear Wheel    Components                    837
# 164     HL Mountain Frame - Black, 38    Components                    834
# 341                LL Road Handlebars    Components                    831
# 207           HL Mountain Front Wheel    Components                    831
# 60   ML Mountain Frame-W - Silver, 38    Components                    826
# 171           ML Mountain Front Wheel    Components                    818
# 249                 LL Bottom Bracket    Components                    814
#
#      units_sold  gross_margin
# 402         426          0.26
# 192         543          0.26
# 250         613          0.26
# 166         676          0.26
# 67           10          0.26
# 61           68          0.26
# 55          444          0.26
# 308         147          0.26
# 242         426          0.26
# 266         190          0.26
# 241         813          0.26
# 2           353          0.26
# 49          500          0.22
# 121          64          0.26
# 164         659          0.03
# 341         213          0.22
# 207         222          0.26
# 60            7          0.09
# 171         266          0.26
# 249         378          0.26

# %%
# Kiểm tra Bundle
slow_products = slow_moving["product_name"].tolist()

bundle_candidates = market_basket[
    market_basket["antecedents"].isin(slow_products)
]

bundle_candidates.head()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
# Đề xuất Promotion

# Nếu sản phẩm:

# Slow Moving
# Margin vẫn tốt

# ⇒ Có thể dùng Promotion.

# Nếu:

# Slow Moving
# Margin thấp

# ⇒ Không nên giảm giá mạnh, nên cân nhắc giảm nhập hàng hoặc loại bỏ.

promotion_candidates = slow_moving[
    slow_moving["gross_margin"] > slow_moving["gross_margin"].median()
]

promotion_candidates[
    [
        "product_name",
        "gross_margin",
        "current_inventory_qty"
    ]
].head(20)
# Out:
#                 product_name  gross_margin  current_inventory_qty
# 2            Rear Derailleur          0.26                    847
# 33         ML Mountain Pedal          0.26                    507
# 41       ML Road Front Wheel          0.26                    793
# 61               ML Crankset          0.26                    905
# 68                HL Headset          0.26                    782
# 72       HL Road Front Wheel          0.26                    678
# 121       ML Road Rear Wheel          0.26                    837
# 126       HL Road Rear Wheel          0.26                    716
# 166            HL Road Pedal          0.26                    906
# 171  ML Mountain Front Wheel          0.26                    818
# 192        HL Bottom Bracket          0.26                    970
# 194              Rear Brakes          0.26                    723
# 207  HL Mountain Front Wheel          0.26                    831
# 242              LL Crankset          0.26                    885
# 258    HL Touring Handlebars          0.26                    792
# 266                  LL Fork          0.26                    863
# 287   Mountain Bike Socks, L          0.40                    216
# 308            Touring Pedal          0.26                    885
# 377   LL Mountain Rear Wheel          0.26                    681
# 408               LL Headset          0.26                    761

# %% [markdown]
# Insight 4: KMeans cho thấy danh mục có thể chia thành bốn chiến lược quản trị khác nhau.

# %%
cluster_summary
# Out:
#          Products      Revenue  Margin  Growth  Discount  Inventory
# Cluster
# 0             187   152,003.38    0.21    0.33      0.00       4.38
# 1              28   664,528.65   -0.01    0.27      0.03       3.75
# 2              41 1,518,429.15    0.06    0.10      0.00      15.93
# 3              10    55,935.15    0.06    4.33      0.00       0.00

# %%
plt.figure(figsize=(10,8))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=cluster_df["Cluster"],
    cmap="Set2",
    alpha=0.8
)

plt.title("Product Clustering using K-Means")

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %%
# Phân bố số lượng sản phẩm
cluster_df["Strategy"].value_counts().plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Distribution of Product Strategy Segments")

plt.ylabel("Products")

plt.show()
